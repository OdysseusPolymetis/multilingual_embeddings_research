# %% [markdown]
# <h1>Unsupervised multilingual embeddings with MUSE and GloVe</h1>

# %% [markdown]
# This Notebook contains the whole chain, from lemmatizing to tensorflow data.

# %%
import pickle
#from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
from typing import List
from pie_extended.cli.utils import get_tagger, get_model, download
#import gensim.downloader
#from transvec.transformers import TranslationWordVectorizer
from glove import Corpus, Glove
import unicodedata
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.cm as cm
from sklearn.manifold import TSNE
import matplotlib

import subprocess
import os
import fnmatch
from lxml import etree as et
import string
import io
import numpy as np
import pandas as pd
#import seaborn as sns

# %%
# %matplotlib ipympl

# %% [markdown]
# <h2>Basic functions</h2>

# %% [markdown]
# Basic functions such as calling home made french tagger from XML files, calling MUSE aligner, generating stopword lists, ...

# %%
def tag(source, target):
    subprocess.call(['java','-jar','tagging.jar', source, target])

# %%
def align_models(source_language, target_language, source_model, target_model):
    subprocess.call(['python', './MUSE/unsupervised.py', '--src_lang', source_language, '--tgt_lang', target_language, '--src_emb', source_model, '--tgt_emb', target_model, '--n_refinement', '5'])

# %%
f = open("stopwords_gk.txt", "r",encoding='utf-8')
stopwords_gk=[]
for word in f.read().split("\n"):
    stopwords_gk.append(unicodedata.normalize("NFD", word))

# %%
f2 = open("stopwords_gk.txt", "r",encoding='utf-8')
stopwords_gk_combined=[]
for word in f2.read().split("\n"):
    stopwords_gk_combined.append(word)

# %%
f = open("stopwords.txt", "r",encoding='utf-8')
stopwords=f.read().split("\n")

# %% [markdown]
# <h2>French Tagging and Parsing</h2>

# %%
tag('./txts/odyssey_fr','./tagged')
tree=et.parse("./tagged/odyssee_fr.xml")

# %%
fr_lemmatized_sentences=[]
for p in tree.findall(".//sentence"):
    sentence=[]
    for word in p.findall(".//word"):
        if word.attrib["lemma"]!=" " and word.attrib["lemma"] not in stopwords and word.attrib["lemma"]!="" and word.attrib["form"] not in string.punctuation:
            sentence.append(word.attrib["lemma"])
    fr_lemmatized_sentences.append(sentence)

# %%
print(fr_lemmatized_sentences)
# Out:
# [['muse', 'sage', 'héros', 'errer', 'long', 'année', 'renverser', 'mur', 'sacré', 'Troie', 'visiter', 'cité', 'apprendre', 'moeurs', 'peuple', 'mer', 'coeur', 'endurer', 'souffrance', 'lutter', 'vie', 'compagnon'], ['prix', 'pouvoir', 'sauver', 'désir', 'vain', 'folie', 'causer', 'perte', 'insensé', 'assouvir', 'faim', 'génisse', 'soleil', 'dieu', 'leu', 'ravir', 'jour'], ['déesse', 'fille', 'Jupiter', 'redire', 'partie', 'malheur'], ['déjà', 'échapper', 'fin', 'terrible', 'patrie', 'sauver', 'guerre', 'flot', 'soupirer', 'foyer', 'époux', 'auguste', 'nymphe', 'Calypso', 'déesse', 'retenir', 'grotte', 'profond', 'brûler', 'faire', 'époux'], ['année', 'remplir', 'cercle', 'amener', 'jour', 'fixer', 'dieu', 'Ithaque', 'devoir', 'soutenir', 'lutte', 'milieu', 'ami'], ['dieu', 'pitié', 'Neptune', 'nourrir', 'long', 'courroux', 'divin', 'Ulysse', 'rentrer', 'patrie'], ['dieu', 'aller', 'visiter', 'éthiopien', 'contrée', 'lointain', 'éthiopien', 'placer', 'limite', 'monde', 'diviser', 'peuple', 'regardant', 'couchant', 'aurore', 'hécatombe', 'taureau', 'brebis', 'réserver'], ['coeur', 'joyeux', 'assister', 'festin', 'dieu', 'réunir', 'palais', 'Jupiter', 'olympien'], ['père', 'dieu', 'homme', 'prendre', 'souvenir', 'coeur', 'noble', 'Ëgisthe', 'venir', 'tuer', 'fils', 'Agamemnon', 'fameux', 'Oreste', 'souvenir', 'adresser', 'immortel', 'homme', 'accuser', 'dieu', 'auteur', 'mal', 'folie', 'destin', 'créer', 'souffrance'], ['Ëgisthe', 'destin', 'uni', 'époux', 'fils', 'Atrée', 'égorger', 'héros', 'voir', 'fin', 'terrible', 'envoyer', 'Mercure', 'vigilant', 'meurtrier', 'argus', 'avertir', 'point', 'tuer', 'point', 'rechercher', 'époux', 'Oreste', 'fils', 'Atrée', 'punir', 'jour', 'grandir', 'désirer', 'revoir', 'patrie'], ['Mercure', 'conseil', 'bienveillant', 'persuader', 'point', 'coeur', 'Égisthe', 'expier'], ['déesse', 'oeil', 'bleu', 'Minerve', 'répondre', 'ensuite', 'fils', 'Saturne', 'père', 'grand', 'roi', 'tomber', 'coup'], ['périr', 'faire', 'faire', 'coeur', 'déchirer', 'penser', 'sage', 'Ulysse', 'infortuné', 'loin', 'ami', 'souffrir', 'île', 'enfermer', 'flot', 'centre', 'mer', 'île', 'riche', 'forêt', 'demeure', 'déesse', 'fille', 'Atlas', 'pernicieux', 'pensée', 'Atlas', 'connaître', 'abîme', 'mer', 'entier', 'soutenir', 'colonne', 'séparer', 'terre', 'cieux'], ['fille', 'retenir', 'malheureux', 'gémir', 'cesse', 'flatter', 'doux', 'caressant', 'faire', 'oublier', 'Ithaque', 'Ulysse', 'vouloir', 'voir', 'fumée', 'élever', 'terre', 'natal', 'souhaiter', 'mourir'], ['coeur', 'toucher', 'roi', 'Olympe', 'sacrifice', 'offrir', 'Ulysse', 'vaisseau', 'grec', 'vaste', 'champ', 'Troie', 'courroux', 'Jupiter', 'Jupiter', 'rassembler', 'nuée', 'répondre', 'fille', 'sortie', 'bouche', 'pouvoir', 'oublier', 'divin', 'Ulysse', 'sage', 'mortel', 'offrir', 'sacrifice', 'dieu', 'habiter', 'vaste', 'ciel', 'Neptune', 'embrasser', 'terre', 'irriter', 'cause', 'cyclope', 'Ulysse', 'priver', 'lumière', 'divin', 'Polyphème', 'puissant', 'cyclope', 'nymphe', 'Thoosa', 'mettre', 'jour', 'fille', 'Phorcyn', 'souverain', 'mer', 'stérile', 'uni', 'Neptune', 'grotte', 'profond'], ['Neptune', 'ébranler', 'terre', 'faire', 'périr', 'Ulysse', 'faire', 'errer', 'loin', 'patrie'], ['voir', 'songer', 'assurer', 'Neptune', 'déposer', 'courroux', 'pouvoir', 'opposer', 'volonté', 'dieu', 'immortel'], ['déesse', 'oeil', 'bleu', 'Minerve', 'répondre', 'ensuite', 'fils', 'Saturne', 'père', 'grand', 'roi', 'plaire', 'dieu', 'bienheureux', 'prudent', 'Ulysse', 'rentrer', 'demeure', 'envoyer', 'aussitôt', 'Mercure', 'messager', 'meurtrier', 'argus', 'Ogygie', 'déclarer', 'nymphe', 'cheveu', 'résolution', 'immuable', 'courageux', 'Ulysse'], ['aller', 'Ithaque', 'animer', 'fils', 'mettre', 'coeur', 'convoquer', 'assemblée', 'grec', 'long', 'chevelure', 'interdire', 'maison', 'prétendant', 'jour', 'égorger', 'foule', 'brebis', 'boeuf', 'lent', 'corne', 'recourbé'], ['envoyer', 'sparte', 'sablonneux', 'Pylos', 'informe', 'père', 'pouvoir', 'apprendre', 'nouvelle', ...

# %% [markdown]
# <h2>Greek Tagging (if in txt format)</h2>

# %% [markdown]
# NB: each line in the txt files must begin with "REF:line_no"
# <br>Here, tagging using pie

# %%
gk_txt=open("./txts/1-4_gk.txt", encoding="utf8").read().splitlines()
gk_text = " ".join([ f"[REF:{line_no}] {line}" for line_no, line in enumerate(gk_txt) ])

# %%
from pie_extended.models.grc.imports import get_iterator_and_processor

greek_pie_model = "grc"
tagger = get_tagger(greek_pie_model, batch_size=256, device="cuda", model_path=None)

# %%
gk_lemmatized_sentences = []
iterator, processor = get_iterator_and_processor()

for form in tagger.iter_tag_token(gk_text, iterator=iterator, processor=processor):
    if form["form"].startswith("[REF:"):
        gk_lemmatized_sentences.append([])
    else:
        if form["lemma"] not in stopwords_gk and form["pos"]!="u" and form["form"] not in string.punctuation:
            gk_lemmatized_sentences[-1].append(form["lemma"])
# Out:
# Ἔνεπος : a
# Μοῦσα : a
# ἀνήρ : n
# πολύτροπος : a
# πλάσσω : a
# πέρθω : v
# πτολίεθρον : n
# ἱερός : n
# Τροία : n
# · : n
# εἶδον : n
# ἄστυ : n
# γιγνώσκω : v
# νόος : n
# ἄνθρωπος : n
# · : n
# πάσχω : n
# πόντος : n
# ἄλγος : n
# θυμός : n
# ἄρνυμαι : v
# ψυχή : n
# νόστος : n
# ἑταῖρος : n
# Ἀλλὰ : c
# ῥύομαι : v
# ἑταῖρος : n
# ἵημι : v
# ὄλλυμι : v
# σφέτερος : a
# ἀτασθαλία : a
# νήπιος : a
# κατεσθίω : a
# βοῦς : n
# ἠέλιος : n
# Ὑπερίων : n
# ἀφαιρέω : v
# ἦμαρ : n
# νόστιμος : a
# Θεά : n
# θυγάτηρ : n
# Ζεύς : n
# ἀμόθεν : d
# φεύγω : v
# ὄλεθρος : a
# αἰπύς : a
# οἴκοι : v
# φεύγω : v
# πόλεμος : n
# θάλασσα : n
# χράω : v
# νόστος : n
# γυνή : n
# πότνια : n
# νύμφη : n
# Καλυψώ : n
# δῖος : n
# θεά : n
# ἐρύκω : v
# σπέος : n
# γλαφυρός : a
# λιλαίομαι : v
# πόσις : n
# Ἀλλὰ : c
# ἐνιαυτός : v
# περιπέλομαι : v
# ἔτος : -
# ἔρχομαι : v
# θεός : n
# ἐπικλώθω : v
# νέομαι : v
# Ἰθάκη : v
# φεύγω : v
# ἆθλος : v
# φίλος : a
# Ἅπας : n
# θεός : n
# ἐλεαίρω : n
# Ποσειδεών : n
# μενεαίνω : v
# ἀσπερχές : d
# Ὀδυσσεύς : n
# ἀντίθεος : a
# ἱκνέομαι : v
# γαῖα : n
# Ἀλλὰ : c
# μετακιάθω : v
# Αἰθίοψ : n
# τηλόθι : d
# Αἰθίοψ : n
# δαίω : v
# διχθά : a
# ἔσχατος : a
# ἀνήρ : n
# Ὑπερίων : n
# δύω : v
# ἄνειμι : v
# ἀντιάω : a
# ἑκατόμβη : n
# ταῦρος : n
# ἀρνειός : n
# ὅσγε : p
# τέρπω : v
# πάρημαι : v
# δαίς : n
# ἀθρόος : a
# μέγαρον : n
# Ζεύς : n
# Ὀλύμπιος : a
# πατήρ : n
# ἀνήρ : n
# θεός : n
# ἄρχω : v
# μῦθος : n
# μιμνόσκω : v
# θυμός : n
# ἀμύμων : a
# Αἴγισθος : n
# Ὀρέστης : n
# Ἀγαμεμνονίδης : n
# τηλεκλυτός : a
# κτείνω : v
# ὅσγε : v
# ἐπιμιμνήσκομαι : v
# μεταυδάω : v
# ἔπος : n
# ἀθάνατος : a
# πόποι : i
# βροτός : n
# αἰτιάομαι : v
# θεός : n
# Φαός : n
# κακός : a
# σφός : a
# ἀτασθαλία : a
# ἄλγος : n
# ὑπέρμορον : a
# Αἴγισθος : n
# ὑπέρμορος : a
# γαμέω : v
# ἄλοχος : n
# μνηστός : a
# Ἀτρείδης : n
# κτείνω : v
# νοστέω : v
# οἶδα : v
# ὄλεθρος : a
# αἰπύς : a
# προεῖπον : v
# πέμπω : v
# Ἑρμῆς : a
# εὔσκοπος : a
# Ἀργειφόντης : n
# κτείνω : v
# μνάομαι : v
# ἄκοιτις : n
# τίσις : n
# Ὀρέστης : n
# Ἀτρείδης : n
# ἄν1 : d
# ἡβάω : v
# ἱμείρω : v
# αἶα : n
# Ἑρμῆς : n
# πείθω : v
# φρήν : n
# Αἴγισθος : n
# φρονέω : v
# ἀγαθός : a
# ἀποτίνω : v
# ἀθρόος : a
# Ἀθήνη : n
# θεά : n
# γλαυκῶπις : a
# ἀμείβω : v
# πάτηρ : n
# Κρονίδης : n
# ὕπατος : a
# κρείων : n
# κεῖμαι : v
# ὄλεθρος : n
# ἔοικα : v
# ἀπόλλυμι : v
# ῥέζω : v
# Ἀλλὰ : c
# ἦτορ : n
# δαίω : n
# Ὀδυσσεύς : n
# δαίφρων : a
# δύσμορος : a
# πάσχω : n
# πῆμα : n
# φίλος : n
# νῆσος : n
# ἀμφίρυτος : a
# ὀμφαλός : n
# θάλασσα : n
# νῆσος : n
# δενδρήεις : a
# θεά : n
# ναίω : n
# δῶμα : n
# θυγάτηρ : n
# Ἄτλας : n
# ὀλοόφρων : a
# ὅστε : a
# οἶδα : n
# βένθος : n
# θάλασσα : n
# μακρός : a
# κίων : n
# γαῖα : n
# οὐρανός : n
# θυγάτηρ : n
# κατερύκω : v
# δύστηνος : a
# ὀδύρομαι : v
# θέλγω : v
# λόγος : n
# μαλακός : a
# αἱμύλος : a
# ἐπιλάω : v
# Ἰθάκη : n
# Ὀδυσσεύς : n
# ἵημι : v
# νοέω : v
# καπνός : n
# ἀποθρῴσκω : v
# γαῖα : v
# ἱμείρω : v
# θνήσκω : v
# φίλος : a
# ἦτορ : n
# ἐντρέπω : v
# Ὀλύμπιος : a
# Ὀδυσσεύς : n
# χαρίζομαι : v
# ῥέζω : v
# ἱερός : n
# ναῦς : n
# Ἀργεῖος : a
# εὐρύς : a
# Τροία : n
# ὀδύσσομαι : v
# Ζεύς : n
# Ζεύς : n
# νεφεληγερέτα : n
# ἀπαμείβομαι : v
# πρόσφημι : v
# τέκνον : n
# ἔπος : n
# φεύγω : n
# ἕρκος : n
# ὀδούς : n
# ἄν1 : d
# λανθάνω : v
# θεῖος : a
# Ὀδυσσεύς : n
# νόος : n
# βροτός : n
# δίδωμι : v
# ἱερός : n
# θεός : n
# ἀθάνατος : a
# εὐρύς : a
# οὐρανός : n
# Ἀλλὰ : a
# Ποσειδεών : n
# γαιήοχος : a
# χολόω : a
# ἀσκελής : a
# Κύκλωψ : n
# ἀλαόω : v
# ὀφθαλμός : n
# Πολύφημος : n
# ἀντίθεος : a
# κράτος : n
# μέγας : a
# Κύκλωψ : n
# νύμφη : n
# Θόωσα : n
# θυγάτηρ : n
# Φόρκυς : n
# μέδων : n
# ἅλς : n
# ἀτρύγετος : a
# τίκτω : v
# μίγνυμι : v
# Ποσειδεών : n
# σπέος : n
# γλαφυρός : a
# Ποσειδεών : n
# Ἐνοσίχθων : n
# κατακτείνω : v
# Ὀδυσσεύς : n
# πλάζω : n
# αἶα : n
# πατρίς : n
# Ἀλλὰ : c
# περιφράζομαι : v
# νόστος : n
# ἔρχομαι : v
# Ποσειδεών : n
# μεθίημι : v
# χόλος : n
# δύναμαι : v
# ἀέκητι : a
# θεός : a
# ἀθάνατος : a
# ἐριδαίνω : v
# ἀντίος : a
# θεά : n
# Ἀθήνη : n
# γλαυκῶπις : a
# ἀμείβω : v
# πάτηρ : n
# Κρονίδης : n
# ὕπατος : a
# κρείων : n
# φίλος : a
# θεός : n
# μάκαρ : n
# δαίφρων : n
# Ὀδυσσεύς : n
# νοστέω : v
# δόμονδε : d
# ὀτρύνω : v
# Ἑρμῆς : n
# διάκτορος : n
# Ἀργειφόντης : n
# νῆσος : n
# ̓ὠγυγία : n
# ταχύς : a
# νύμφη : n
# εὐπλόκαμος : a
# βουλή : n
# νημερτής : a
# νόστος : n
# Ὀδυσσεύς : n
# ταλασίφρων : a
# νέομαι : v
# εἰσέρχομαι : v
# Ἰθάκη : n
# ἐποτρύνω : v
# υἱός : n
# τίθημι : v
# φρήν : n
# μένος : n
# καλέω : v
# ἀγορά : n
# Ἀχαιός : n
# καρηκομάω : v
# ἀπεῖπον : v
# μνηστήρ : n
# ὅστε : n
# σφάζω : v
# μῆλον : n
# ἀδινός : a
# βοῦς : n
# εἰλίπους : n
# ἕλιξ : n
# πέμπω : n
# Σπάρτη : n
# Πύλος : n
# ἠμαθόεις : a
# πυνθάνομαι : v
# νόστος : n
# πατήρ : n
# φίλος : a
# ἀκούω : v
# ἐσθλός : a
# κλέος : n
# ἄνθρωπος : n
# δέω : v
# πούς : n
# καλός : a
# πέδιλον : n
# ἀμβρόσιος : a
# χρύσεος : a
# φέρω : -
# ῥηρός : a
# γαῖα : n
# ἀπείρων : a
# πνοή : n
# ἄνεμος : n
# Εἵλομαι : v
# ἔγχος : n
# ἄλκιμος : a
# ἀκαχμένος : a
# χαλκός : a
# ὀξύς : a
# βριθύς : a
# μέγας : a
# στιβαρός : a
# δάμνημι : n
# στίξ : n
# ἀνήρ : n
# ἥρως : n
# κοτέω : v
# οβριμοπάτρη : n
# Ἀίξης : n
# βαίνω : v
# κάρηνον : n
# Ὄλυμπος : n
# · : n
# ἵστημι : v
# δῆμος : n
# Ἰθάκη : n
# πρόθυρον : n
# Ὀδυσσεύς : n
# οὐδός : n
# αὔλειος : n
# παλάμη : n
# ἔγχος : n
# χάλκεος : a
# εἴδομαι : v
# ξένος : n
# Μέντης : n
# ἡγήτωρ : n
# Τάφιος : n
# Εὑρέω : n
# μνηστήρ : n
# ἀγήνωρ : n
# · : n
# τέρπω : a
# θυμός : n
# πεσσός : n
# θύρα : n
# ἧμαι : v
# ῥινός : n
# βοῦς : v
# κτείνω : v
# Αὐτός : n
# κῆρυξ : n
# θεράπων : n
# ὀτρηρός : a
# μίσγω : v
# οἶνος : n
# ὕδωρ : n
# κρατήρ : n
# νίζω : v
# τράπεζα : n
# σπόγγος : a
# πολύτρητος : a
# προτίθημι : v
# ἰδέ : n
# δατέομαι : v
# κρέας : n
# Τηλέμαχος : n
# θεοειδής : a
# εἶδον : a
# πρῶτος : a
# ἧμαι : v
# μνηστήρ : n
# τετίημαι : v
# φίλος : n
# ἦτορ : n
# ὄσσομαι : v
# φρήν : n
# πατήρ : n
# ἐσθλός : a
# ἔρχομαι : v
# ποθεν : v
# τίθημι : v
# σκέδασις : n
# μνηστήρ : n
# δῶμα : n
# τιμή : n
# ἀνάσσω : v
# κτῆμα : n
# Φρονέων : n
# μέθημαι : v
# μνηστήρ : n
# εἰσοράω : v
# Ἀθήνη : n
# βαίνω : v
# πρόθυρον : n
# νεμεσάω : v
# θυμός : n
# ξένος : v
# ἐφίστημι : v
# θύρα : v
# ἵστημι : v
# ἐγγύθι : v
# αἱρέω : v
# χείρ : n
# δεξιτερός : a
# δέχομαι : v
# ἔγχος : n
# χάλκεος : a
# φωνέω : v
# προσαυδάω : v
# ἔπος : n
# πτερόεις : a
# Χαίρω : n
# ξένος : n
# φιλέω : v
# πατέομαι : v
# δεῖπνον : v
# μυθέομαι : v
# χρή : v
# ἡγέομαι : v
# Παλλάς : n
# Ἀθήνη : n
# ἕπομαι : v
# δόμος : n
# ὑψηλός : a
# ἵστημι : v
# ἔγχος : n
# φέρω : v
# κίων : n
# μακρός : a
# δουροδόκη : n
# εὔξοος : a
# ἵστημι : v
# ἔγχος : n
# Ὀδυσσεύς : n
# ταλασίφρων : a
# ἵζω : v
# ἄγω : v
# θρόνος : n
# ὄλλυμι : v
# Ἀλλά : c
# καταλέγω : v
# ἀτρεκής : d
# · : d
# ἀνήρ : d
# ; : d
# πόθι : d
# πόλις : n
# τοκεύς : n
# ὁποῖος : d
# ναῦς : n
# ἀφικνέομαι : v
# ναύτης : n
# ἄγω : v
# Ἰθάκη : n
# ; : v
# εὐχετάομαι : v
# ; : v
# οἴομαι : v
# ἱκνέομαι : v
# πεζός : a
# ἀγορεύω : v
# ἐτήτυμος : a
# οἶδα : v
# μεθέπω : v
# νέος : a
# ξένος : a
# πατρώιος : a
# ἀνήρ : n
# οἶδα : v
# δῶμα : n
# ἐπίστροφος : a
# ἄνθρωπος : n
# Θεά : n
# Ἀθήνη : n
# γλαυκῶπις : a
# προσεῖπον : v
# Τοιγάρ : n
# ἀγορεύω : v
# ἀτρεκής : d
# Εὔχομαι : n
# Μέντης : n
# υἱός : n
# δαίφρων : a
# Ἀγχίαλος : n
# ἀνάσσω : v
# Τάφιοι : a
# φιλήρετμος : a
# κατέρχομαι : v
# ναῦς : n
# ἑταῖρος : n
# πλείων : a
# πόντος : n
# οἶνοψ : n
# ἄνθρωπος : n
# ἀλλόθροος : a
# Τεμέως : n
# χαλκός : n
# ἄγω : n
# σίδηρος : n
# αἴθων : a
# Ναῦς : n
# ἵστημι : v
# ἀγρός : n
# πόλις : n
# λιμήν : n
# Ῥεῖθρον : n
# Νήιον : a
# ὑλήεις : a
# Εὔχομαι : v
# ξένος : n
# πατρώιος : a
# ἀρχή : n
# ἐπέρχομαι : v
# ἔρομαι : v
# γέρων : n
# Λαέρτης : n
# ἥρως : v
# ἔρχομαι : v
# πόλινδε : d
# πάσχω : v
# πῆμα : n
# ἀγρός : n
# γράυς : n
# ἀμφίπολος : a
# παρτίθεμι : v
# βρῶσις : n
# πόσις : n
# ἄν1 : d
# κᾶμα : n
# καταλαμβάνω : n
# γυῖον : n
# ἑρπύζω : n
# γουνός : n
# ἀλωή : n
# οἰνόπεδος : a
# ἔρχομαι : v
# πατήρ : n
# ἐπιδήμιος : a
# θεός : n
# βλάπτω : v
# ὅσγε : a
# κέλευθος : n
# Ζεύς : n
# Ὀδυσσεύς : n
# θνήσκω : v
# χθών : n
# ζωός : a
# κατερύκω : v
# εὐρύς : a
# πόντος : n
# νῆσος : n
# ἀμφίρυτος : a
# ἀνήρ : n
# χαλεπός : a
# ἄγριος : a
# ἐρυκανάω : v
# ἀέκων : a
# μαντεύομαι : v
# ἀθάνατος : a
# βάλλω : v
# θυμός : v
# οἴομαι : v
# τελέω : v
# μάντις : v
# οἶδα : v
# σάφα : d
# οἰωνός : v
# · : d
# οὔτοι : d
# δηρός : a
# φίλος : a
# αἶα : n
# πατρίς : n
# δέσμα : n
# σιδήρεος : a
# φράζω : v
# νέομαι : v
# πολυμήχανος : a
# Ἀλλὰ : c
# καταλέγος : v
# ἀτρεκής : d
# Ὀδυσσεύς : n
# Ἔοικα : n
# αἰνός : d
# κεφαλή : n
# καλός : a
# ὄμμα : n
# μίγνυμι : v
# θαμά : d
# ἀναβαίνω : v
# Τροία : a
# ἄριστος : a
# Ἀργεῖος : a
# βαίνω : v
# ναῦς : n
# κοῖλος : a
# εἶδον : v
# Ὀδυσσεύς : a
# Τηλέμαχος : n
# πέπνυμαι : v
# αὐδάω : v
# ἀντίος : a
# Τοιγάρ : n
# ξένος : a
# ἀγορεύω : v
# ἀτρεκής : d
# Μήτηρ : n
# οἶδα : v
# · : d
# ἀναγιγνώσκω : v
# γόνος : n
# ὀφείλω : v
# υἱός : n
# ἀνήρ : n
# μάκαρος : n
# γῆρας : n
# τέτμον : v
# κτέαρ : n
# ἄποτμος : a
# ἄνθρωπος : n
# θνητός : a
# ἐρεείνω : v
# Θεά : n
# Ἀθήνη : n
# γλαυκῶπις : a
# προσεῖπον : v
# Θεός : n
# τίθημι : n
# γενεά : n
# νώνυμνος : a
# Πηνελόπεια : n
# γείνομαι : v
# Ἀλλὰ : c
# καταλέγω : v
# ἀτρεκής : d
# δαίς : n
# ὅμιλος : n
# πέλω : v
# τίπτε : p
# χρεώ : p
# εἰλαπίνη : a
# γάμος : n
# ἔρανος : v
# · : d
# δοκέω : v
# ὑβρίζω : v
# ὑπερφίαλος : d
# δαίνυμι : v
# δῶμα : v
# ἀνήρ : n
# νεμεσάω : v
# ὁράω : v
# αἶσχος : a
# πινυτός : a
# μετέρχομαι : v
# Τηλέμαχος : n
# πέπνυμαι : v
# αὐδάω : v
# ἀντίος : a
# Ξείνω : v
# ἀνέρομαι : v
# μεταλλάω : v
# οἶκος : d
# μέλλω : v
# ἀφνειός : a
# ἀμύμων : a
# ἀνήρ : n
# ἐπιδήμιος : a
# · : d
# θεός : n
# μητιάω : v
# κακός : a
# βούλομαι : v
# ἄιστος : a
# ἄνθρωπος : n
# ἀχεύω : v
# θνήσκω : v
# δαμά : v
# ἑταῖρος : n
# δῆμος : n
# Τρώς : n
# χείρ : n
# φίλος : n
# τολυπεύω : v
# πόλεμος : n
# Παναχαιοί : a
# τύμβος : n
# αἴρω : v
# μέγας : a
# κλέος : n
# Ἅρπυιαι : a
# ἀνερείπομαι : v
# ἀκλεής : d
# οἴχομαι : v
# ἄιστος : a
# ἄπυστος : a
# καταλείπω : v
# ὀδύνη : n
# γόος : n
# στεναχίζω : v
# ὀδύρομαι : v
# θεός : n
# τεύχω : v
# κακός : a
# κῆδος : n
# ἄριστος : a
# ἐπικρατέω : v
# νῆσος : n
# δουλίχιος : a
# Σάμη : n
# Ζάκυνθος : n
# ὑλήεις : a
# κοιρανέω : v
# κραναός : a
# Ἰθάκη : n
# μνάομαι : v
# μήτηρ : n
# τρύχω : v
# οἶκος : n
# ἀρνέω : v
# γάμος : v
# στυγερός : a
# δύναμαι : v
# τέλειος : p
# ἔδω : v
# φθινύθω : v
# οἶκος : v
# διαρραίω : v
# Παλλάς : n
# Ἀθήνη : n
# ἐπαλαστέω : v
# προσαυδάω : v
# πόποι : i
# δέω : v
# Ὀδυσσεύς : n
# ἀποίχομαι : v
# ἐφίημι : v
# χείρ : n
# μνηστήρ : n
# ἀναιδής : a
# ἔρχομαι : v
# ἵστημι : v
# πρῶτος : a
# θύρα : n
# δόμος : n
# πήληξ : n
# ἀσπίς : n
# δύο : a
# δόρυ : v
# νοέω : v
# πρῶτος : a
# πίνω : v
# τέρπω : v
# οἶκος : n
# ἄνειμι : v
# Ἐφύρα : n
# Ἴλλος : n
# Μερμερίδης : n
# Ὀδυσσεύς : n
# οἴχομαι : v
# ναῦς : n
# θοός : a
# δίζημαι : v
# φάρμακον : n
# ἀνδροφόνος : a
# χρίω : v
# ἰός : v
# χαλκήρης : a
# δίδωμι : v
# νεμεσίζομαι : v
# θεός : v
# πατήρ : n
# δίδωμι : v
# φιλέω : v
# αἰνός : d
# Ὀδυσσεύς : n
# ὁμιλέω : v
# μνηστήρ : n
# ὠκύμορος : a
# πικρόγαμος : a
# Ἀλλὰ : c
# κεῖμαι : v
# γόνυ : v
# θεός : v
# νοστέω : v
# ἀποτίνω : v
# μέγαρον : v
# ἄνωγα : v
# φράζω : v
# ἀπωθέω : v
# μνηστήρ : n
# μέγαρον : n
# συνίημι : v
# ἐμπάζομαι : v
# μῦθος : n
# αὔριον : a
# καλέω : v
# ἀγορά : n
# ἥρως : n
# Ἀχαιός : n
# φράζω : v
# μῦθος : n
# θεός : n
# ἐπιμάρτυρος : a
# Ἄνωχθε : n
# μνηστήρ : n
# σκίδνημι : v
# σφέτερος : a
# μήτηρ : n
# θυμός : n
# ἐφορμάω : v
# γαμέω : v
# μέγαρον : n
# πατήρ : n
# δύναμαι : v
# μέγας : a
# τεύχω : v
# γάμος : n
# ἀρτύνω : v
# ἕδνον : n
# ἔοικα : v
# ἕπομαι : v
# φίλος : a
# ὑποθέω : v
# πυκινός : d
# πείθω : v
# ἀραρίσκω : v
# ναῦς : n
# εἴκοσι : v
# ἐρέτης : n
# ἄριστος : a
# ἔρχομαι : v
# πυνθάνομαι : v
# πατήρ : n
# οἴχομαι : v
# βροτός : n
# ἀκούω : v
# Ζεύς : n
# ὅστε : p
# φέρω : v
# κλέος : n
# ἄνθρωπος : n
# πρῶτος : n
# ἔρχομαι : v
# Πύλος : n
# ἔρομαι : v
# δῖος : a
# Νέστωρ : n
# Σπάρτηνδε : d
# ξανθός : a
# Μενέλαος : n
# ἔρχομαι : v
# δεύτατος : a
# Ἀχαιός : a
# χαλκοχίτων : a
# ἀκούω : v
# βίοτος : n
# νόστος : n
# πατήρ : n
# τλάω : v
# ἄν1 : d
# ἐνιαυτός : d
# τρύχω : v
# ἀκούω : v
# θνήσκω : v
# νοστέω : v
# φίλος : a
# γαῖα : n
# πατρίς : n
# χέω : n
# σῆμα : n
# κτερεΐζω : v
# κτέρεα : n
# ἔοικα : v
# δίδωμι : v
# μήτηρ : n
# ἀνήρ : n
# τελευτάω : v
# ἔρδω : v
# φράζω : v
# φρήν : n
# θυμός : n
# κτείνω : v
# μνηστήρ : n
# μέγαρον : n
# δόλος : n
# ἀμφαδόν : d
# χρή : v
# ὀχέω : v
# νηπιέης : a
# τηλίκος : a
# ἀίω : v
# κλέος : n
# δῖος : a
# Ὀρέστης : n
# λαμβάνω : v
# ἄνθρωπος : n
# κτείνω : v
# πατροφονεύς : n
# Αἴγισθος : n
# δολομήτης : a
# κτεί : a
# πατήρ : n
# κλυτός : a
# φίλος : a
# ὁράω : a
# καλός : a
# μέγας : a
# ἄλκιμος : a
# ὀψίγον : a
# κατέρχομαι : v
# ναῦς : n
# θοός : a
# ἑταῖρος : n
# ἀσχαλάω : v
# μένω : v
# μέλω : v
# ἐμπάζομαι : v
# μῦθος : n
# Τηλέμαχος : n
# πέπνυμαι : v
# αὐδάω : v
# ἀντίος : a
# Ξείνων : v
# ἀγορεύω : v
# φρονέω : v
# φίλος : a
# πατήρ : n
# οὔποτε : d
# λάω : v
# Ἀλλὰ : c
# ἐπιμένω : v
# ἐπείγω : v
# ὁδός : v
# λούω : v
# τέρπω : v
# φίλος : n
# κῆρ : n
# κίω : v
# ναῦς : n
# δῶρον : v
# χαίρω : v
# θυμός : n
# τιμήεις : v
# καλός : a
# κειμήλιον : a
# ξένος : n
# φίλος : a
# δίδωμι : v
# ξένος : n
# θεά : n
# Ἀθήνη : n
# γλαυκῶπις : a
# ἀμείβω : v
# κατερύκω : v
# λιλαίομαι : v
# ὁδός : n
# δῶρον : n
# φίλος : a
# ἦτορ : v
# ἄνωγα : v
# δίδωμι : v
# δίδωμι : v
# ἀνέρχομαι : v
# φέρω : v
# αἱρέω : v
# καλός : a
# ἄξιος : a
# ἀμοιβή : n
# Ἀθήνη : n
# γλαυκῶπις : a
# ἀποβαίνω : v
# διαπέταμαι : v
# ἀνοπαῖος : n
# ὄρνις : n
# τίθημι : v
# θυμός : n
# μένος : n
# θάρσος : n
# ὑπομιμνήσκω : v
# ἕ : p
# πατήρ : n
# νοέω : v
# φρήν : n
# θαμβέω : v
# θυμός : n
# οἴομαι : v
# θεός : n
# Αὐτίκα : d
# φώς : n
# ἰσόθεος : a
# ἐποίχομαι : v
# μνηστήρ : n
# Ἀοιδός : n
# περικλυτός : a
# ἀείδω : v
# ἧμαι : v
# ἀκούω : v
# σιωπή : n
# ἀείδω : v
# νόστος : n
# λυγρός : a
# Ἀχαιός : n
# Παλλάς : n
# Ἀθήνη : n
# ἐπιτέλλω : v
# Τροία : n
# Ὑπερωιόθεν : d
# κόρη : n
# Ἰκάριος : n
# περίφρων : n
# Πηνελόπεια : n
# συντίθημι : v
# φρήν : n
# ἀοιδή : n
# θέσπις : n
# καταβαίνω : v
# κλῖμαξ : n
# ὑψηλός : a
# δόμος : a
# δύο : a
# ἀμφίπολος : a
# ἕπομαι : v
# δῖος : a
# γυνή : n
# ἀφικνέομαι : v
# μνηστήρ : n
# ἵστημι : v
# σταθμός : n
# τέγος : n
# ποιητός : a
# πύκα : d
# παρειά : n
# κρήδεμνον : n
# λιπαρός : a
# κεδνός : a
# ἀμφίπολος : a
# παρίστημι : v
# ἑκάτερθε : d
# δακρύω : v
# προσαυδάω : v
# ἀοιδός : n
# θεῖος : n
# Φήμιος : n
# οἶδα : v
# θελκτήριον : n
# βροτός : n
# ἔργον : n
# οἶκος : n
# δοκέω : v
# λωίων : a
# ἀμείνων : a
# ὄλλυμι : v
# νήποινος : a
# βίοτος : n
# εἷς : n
# ἀνήρ : n
# κείρω : v
# ἐπιβόω : v
# θεός : v
# Ζεύς : n
# δίδωμι : v
# ἔργον : n
# παλίντιτος : a
# ὄλλυμι : v
# νήποινος : a
# δόμος : n
# Ἔφημος : d
# ἐμφύω : v
# ὀδάξ : d
# χεῖλος : n
# θαυμάζω : v
# Τηλέμαχος : n
# ἀγορεύω : v
# θαρσαλέος : d
# Ἀντίνοος : n
# υἱός : n
# Εὐπείθης : n
# πρόσφημι : -
# Τηλέμαχος : n
# θεός : n
# διδάσκω : v
# ὑψαγόρας : v
# ἀγορεύω : v
# θαρσαλέος : d
# Κρονίων : n
# βασιλεύς : n
# Ἰθάκη : n
# ἀμφίαλος : a
# πατρώιος : a
# γενεά : n
# αὐδάω : v
# ἀντίος : a
# Ἀντίνοος : v
# ἀγάσσεα : v
# ἐθέλω : v
# αἴρω : v
# Ζεύς : a
# δίδωμι : v
# τεύχω : v
# κακός : a
# ἄνθρωπος : n
# ; : d
# Τηλέμαχος : n
# πέπνυμαι : v
# βασιλεύω : v
# κακός : a
# · : d
# δίδωμι : v
# ἀφνειός : a
# πέλω : v
# τιμήεις : a
# Ἀλλὰ : c
# βασιλεύς : n
# Ἀχαιός : a
# Ἰθάκη : n
# ἀμφίαλος : a
# νέος : a
# παλαιός : a
# δῖος : a
# Ὀδυσσεύς : n
# θνήσκω : v
# ἄναξ : n
# οἶκος : n
# δμῶος : n
# δῖος : a
# Ὀδυσσεύς : n
# ληίζομαι : v
# Εὐρύμαχος : n
# Πόλυβος : n
# αὐδάω : v
# Τηλέμαχος : n
# κεῖμαι : v
# γόνυ : n
# θεός : n
# Ἀχαιός : n
# βασιλεύω : v
# Ἰθάκη : n
# ἀμφίαλος : a
# κτῆμα : n
# ἀνάσσω : v
# δῶμα : n
# ἔρχομαι : v
# ὅσγε : d
# ἀνήρ : n
# βία : n
# ἀπορραίω : n
# κτῆμα : n
# ἀέκων : a
# Ἰθάκη : n
# ναιετάω : v
# Ἀλλὰ : c
# ἐθέλω : v
# φέριστος : a
# ἔρομαι : v
# ξένος : n
# ὁπόθεν : d
# ἀνήρ : n
# πόα : n
# γαῖα : n
# εὔχομαι : v
# γενέα : v
# ἄρουρα : n
# πατρίς : n
# φέρω : v
# ἀγγελία : n
# πατήρ : n
# ἔρχομαι : v
# ἱκάνω : v
# ἔλδομαι : v
# χρέος : a
# ἀναίσσω : v
# οἴχομαι : v
# ὑπομένω : v
# γιγνώσκω : v
# ἔοικα : v
# ὤψ : n
# κακός : a
# Τηλέμαχος : n
# πέπνυμαι : v
# αὐδάω : v
# ἀντίος : a
# Εὐρύμαχος : n
# νόστος : n
# πατήρ : n
# ἀπόλλυμι : v
# πείθω : v
# ἀγγελία : v
# ποθεν : v
# ἔρχομαι : v
# ἐμπάζομαι : v
# θεοπροπία : n
# μήτηρ : n
# ἐξέρομαι : v
# καλέω : v
# θεοπρόπος : n
# μέγαρον : n
# ξένος : n
# πατρώιος : a
# Τάφος : n
# · : n
# εὔχομαι : v
# Μέντης : n
# υἱός : n
# Ἀγχίαλος : n
# δαίφρων : a
# ἀνάσσω : v
# Τάφιοι : n
# φιλήρετμος : a
# Τηλέμαχος : n
# γιγνώσκω : v
# φρήν : n
# θεός : n
# ἀθάνατος : a
# τρέπω : v
# ὀρχηστύς : n
# ἀοιδή : n
# ἱμερόεις : a
# τέρπω : v
# μένω : v
# ἕσπερος : a
# ἐπέρχομαι : v
# τέρπω : v
# ἕσπερος : a
# μέλας : a
# ἐπέρχομαι : v
# κατακείω : v
# βαίνω : v
# Τηλέμαχος : n
# βαίνω : v
# εὐνή : n
# αὐλή : n
# περικαλλής : a
# θάλαμος : n
# ὑψηλός : a
# δαμάζω : v
# χῶρος : n
# περίσκεπτος : a
# μερμηρίζω : v
# φρήν : n
# Ἅμα : n
# Εὐρύκλεια : n
# οἶδα : v
# κεδνός : a
# φέρω : v
# δαίς : n
# αἴθω : v
# θυγάτηρ : n
# Ὤπος : n
# Πεισηνορίδης : n
# Λαέρτης : n
# πρίαμαι : v
# κτέαρ : n
# πρωθήβης : a
# δίδωμι : v
# εἰκοσάβοια : a
# τίω : p
# μέγαρον : n
# ἴσος : a
# κεδνός : a
# ἄλοχος : n
# οὔποτε : d
# μίγνυμι : v
# εὐνή : n
# ἀλεείνω : v
# χόλος : n
# γυνή : n
# φέρω : v
# δαίς : n
# αἴθω : v
# φιλέω : v
# ἕ : -
# δμώς : v
# τρέφω : v
# τυτθός : a
# οἴγω : n
# θύρα : n
# θάλαμος : n
# ποιητός : a
# πύκα : d
# ἕζομαι : v
# λέκτρον : n
# ἐκδύω : v
# μαλακός : a
# χιτών : n
# ἐμβάλλω : v
# χείρ : n
# γραῖα : n
# πυκιμηδής : a
# πτύσσω : v
# ἀσκέω : v
# χιτών : n
# ἀνακρεμάννυμι : v
# πάσσαλος : n
# λέχος : n
# τρητός : n
# βαίνω : v
# θάλαμος : n
# ἐπερύω : v
# θύρα : n
# κορώνη : n
# ἀργύρεος : n
# τανύω : v
# κλείς : n
# ἱμάς : n
# ὅσγε : p
# παννύχιος : a
# καλύπτω : v
# ἄωτον : n
# ὄις : n
# βουλεύω : v
# φρήν : n
# ὁδός : n
# Ἀθήνη : n
# φράζω : v
# φαίνω : n
# ἠώς : n
# ἠριγένεια : n
# ῥοδοδάκτυλος : a
# υἱός : n
# φίλος : n
# Ὀδυσσεύς : n
# ὄρνυμι : v
# εὐνή : n
# ἕννυμι : v
# εἷμα : n
# περιτίθημι : v
# ὦμος : n
# ξίφος : n
# ὀξύς : a
# δέω : v
# πούς : n
# λιπαρός : a
# καλός : a
# πέδιλον : n
# βαίνω : v
# θάλαμος : n
# ἐναλίγκιος : a
# θεός : n
# ἄντην : d
# Αἶψα : n
# κελεύω : v
# κῆρυξ : n
# λιγύφθογγος : a
# κηρύσσω : v
# ἀγορήνδε : d
# Ἀχαιός : a
# καρηκομάω : v
# κηρύσσω : v
# ἀγείρω : v
# ἀγείρω : v
# ὁμηγερής : a
# βαίνω : v
# ἀγορά : n
# παλάμη : n
# ἔγχος : n
# χάλκεος : a
# ὅσδε : a
# κύων : n
# ἀργός : a
# πούς : n
# ἕπομαι : v
# Ἀθήνη : n
# καταχεύω : v
# οἷγα : v
# χάρις : n
# θεσπέσιος : a
# λαός : n
# θεάομαι : v
# ἐπέρχομαι : v
# ἕζομαι : v
# θᾶκος : n
# πατήρ : n
# γέρων : n
# εἴκω : v
# ἥρως : n
# Αἰγύπτιος : a
# ἄρχω : v
# ἀγορεύω : v
# κυφός : n
# γῆρας : n
# οἶδα : v
# μυρίος : a
# υἱός : n
# φίλος : n
# βαίνω : n
# Ὀδυσσεύς : n
# ἀντίθεος : a
# Ἴλιος : n
# εὔπωλος : a
# ναῦς : n
# κοῖλος : a
# Ἄντιφος : n
# αἰχμητής : n
# · : n
# ἄγριος : a
# Κύκλωψ : n
# κτείνω : v
# σπέος : n
# γλαφυρός : a
# ὁπλίζω : v
# πύματος : a
# δόρπον : n
# Τρεῖς : n
# ὁμιλέω : v
# μνηστήρ : a
# Εὐρύνομος : a
# δύο : a
# ἔργον : n
# πατρώιος : d
# λανθάνω : v
# ὀδύρομαι : v
# ἀχεύω : v
# ὅσγε : v
# δακρυχέων : v
# ἀγοράομαι : v
# μετεῖπον : v
# Κόκλυτος : v
# Ἰθακήσιος : a
# ἀγορά : n
# θόωκος : n
# δῖος : a
# Ὀδυσσεύς : n
# βαίνω : v
# ναῦς : n
# κοῖλος : a
# ἀγείρω : v
# χρεώ : a
# ἵκω : v
# ἀνήρ : n
# νέος : v
# προγενής : a
# ; : -
# κλυός : v
# ἀγγελία : v
# στρατός : v
# ἔρχομαι : v
# σάφα : v
# πυνθάνομαι : v
# πρότερος : a
# πιφαύσκω : v
# ἀγορεύω : v
# δήμιος : a
# Δοκέω : v
# ἐσθλός : a
# ὀνίνημι : v
# εἴθε : d
# Ζεύς : n
# τελέω : v
# ἀγαθός : a
# ἕ : p
# μενοινάω : v
# φρήν : n
# Φῆτος : n
# υἱός : n
# φίλος : n
# Ὀδυσσεύς : n
# χαίρω : v
# φήμη : n
# ἧμαι : v
# μενοινάω : v
# ἀγορεύω : v
# Στή : n
# μέσος : n
# ἀγορά : n
# κῆρυξ : n
# Πεισήνωρ : n
# οἶδας : v
# μῆδος : n
# πέπνυμαι : v
# ἐμβάλλω : v
# σκῆπτρον : n
# χείρ : n
# προσεῖπον : v
# γέρων : v
# καθάπτω : v
# πρῶτος : a
# γέρων : n
# ἀνήρ : n
# οἶδα : v
# ἀγείρω : v
# λαός : n
# ἄλγος : n
# ἱκάνω : v
# κλύω : v
# ἀγγελία : n
# στρατός : v
# ἔρχομαι : v
# σάφα : d
# πυνθάνομαι : v
# πρότερος : a
# πιφαύσκω : v
# ἀγορεύω : v
# δήμιος : a
# χρέος : a
# κακός : a
# ἐμπίπτω : p
# οἶκος : a
# δοιοί : a
# ἀπόλλυμι : v
# πατήρ : n
# ἐσθλός : a
# βασιλεύω : v
# πατήρ : d
# ἤπιος : a
# μέγας : a
# διαρραίω : d
# οἶκος : d
# ἀπόλεσις : v
# βίοτος : n
# Μνηστήρ : n
# ἐπιχράω : v
# μήτηρ : n
# ἐθέλω : v
# υἱός : n
# φίλος : n
# ἀνήρ : n
# ἄριστος : a
# ἀπορριγέω : v
# νέομαι : v
# οἶκος : n
# πατήρ : n
# Ἰκάριος : n
# ἑδνόω : v
# θυγάτηρ : n
# δίδωμι : v
# ἐθέλω : v
# ἔρχομαι : v
# χαρίζομαι : v
# πωλέομαι : v
# ἦμαρ : v
# ἱερεύω : v
# βοῦς : n
# ὄις : n
# αἴξ : n
# πίων : a
# εἰλαπινάζω : v
# πίνω : v
# οἶνος : a
# αἶθοψ : a
# μαψίδιος : d
# κατάνομαι : v
# ἀνήρ : n
# Ὀδυσσεύς : n
# ἀμύνω : v
# ἀρή : n
# οἶκος : n
# ἀμύνω : v
# λευγαλέος : d
# δάω : v
# ἀλκή : n
# ἀμύνω : v
# ἄν1 : d
# δύναμις : n
# πάρειμι : v
# Ἔργος : d
# ἀνσχετός : d
# τεύχω : d
# καλός : d
# οἶκος : n
# διόλλυμι : a
# Νεμεσήω : v
# αἰδέομαι : v
# ἄνθρωπος : n
# περικτίονες : n
# περιναιετάω : v
# ὑποδείδω : v
# μῆνις : n
# θεός : n
# μεταστρέφω : v
# ἄγαμαι : v
# ἔργον : n
# κακός : a
# Λίσσομαι : n
# Ζεύς : n
# Ὀλύμπιος : a
# θέμις : n
# ὅστε : p
# λύω : v
# καθίζω : v
# ἀγορά : n
# ἀνήρ : n
# φίλος : a
# ἐάω : v
# τείρω : v
# πένθος : a
# λυγρός : a
# πατήρ : n
# ἐσθλός : a
# Ὀδυσσεύς : n
# δυσμενής : a
# ῥέζω : v
# κακός : a
# Ἀχαιός : a
# ἐυκνήμις : a
# ἀποτίνω : v
# ῥέζω : v
# κακός : a
# δυσμενέων : v
# ὀτρύνω : v
# κερδίων : a
# ἔσθω : v
# κειμήλιον : n
# πρόβασις : n
# φαγεῖν : v
# τίσις : d
# ἄν1 : d
# ποτιπτύσσω : v
# ἄν1 : d
# μῦθος : n
# ἄστυ : n
# ἀπαιτίζω : v
# χρῆμα : n
# ἀποδίδωμι : v
# ἐμβάλλω : v
# θυμός : n
# ὀδύνη : n
# ἄπρακτος : a
# Φάτος : n
# χώομαι : v
# προσβάλλω : n
# σκῆπτρον : n
# γαῖα : n
# ἀναπρήθω : v
# δάκρυον : n
# οἶκτος : n
# αἱρέω : v
# λαός : n
# ἀκήν : d
# τλάω : v
# ἀμείβω : v
# Τηλέμαχος : n
# μῦθος : n
# χαλεπός : a
# Ἀντίνοος : n
# ἀμείβω : v
# προσεῖπον : v
# Τηλέμαχος : n
# ὑψαγόρας : n
# ἄσχετος : a
# μένος : n
# αἰσχύνω : v
# ἐθέλω : v
# ἀνάπτω : v
# μῶμος : v
# Μνηστήρ : n
# Ἀχαιός : a
# αἴτιος : a
# μήτηρ : n
# φίλος : a
# οἶδα : v
# κέρδος : n
# τρίτος : d
# ἔτος : d
# τέταρτος : d
# ἀτέμβω : a
# θυμός : n
# Ἀχαιός : n
# στῆθος : n
# Ἔλπεις : v
# ὑπίσχέ : v
# ἀνήρ : n
# προίημι : v
# ἀγγελία : n
# νόος : n
# μενοινάω : v
# μερμηρίζω : v
# φρήν : n
# δόλος : n
# ἵστημι : v
# μέγας : a
# ἱστός : n
# μέγαρον : n
# ὑφαίνω : v
# λεπτός : a
# περίμετρος : n
# μετεῖπον : v
# Κοῦρος : n
# μνηστήρ : n
# δῖος : a
# Ὀδυσσεύς : n
# θνήσκω : v
# ἐπείγω : v
# γάμος : n
# μίμνω : v
# εἰσόκε : v
# ἐκτελέω : v
# φᾶρος : n
# νῆμα : n
# ὄλλυμι : v
# μεταμώνιος : a
# ταφήιος : a
# ἥρως : n
# Λαέρτης : n
# μοῖρα : n
# ὀλοός : a
# ̆ : r
# θάνατος : n
# τανηλεγής : a
# καθαίλομαι : v
# Ἀχαιίς : n
# νεμεσάω : v
# δῆμος : n
# καίω : n
# ἄτερ : r
# σπεῖρον : n
# κτεατίζω : v
# Ἔφημος : d
# θυμός : n
# ἀγήνωρ : a
# ἐπιπείθομαι : v
# ἠμάτιος : a
# ὑφαίνω : v
# μέγας : a
# ἱστός : n
# νύξ : n
# ἀναλύω : v
# παρατίθημι : v
# δαίς : n
# τριέτης : a
# λανθάνω : v
# δόλος : n
# πείθω : v
# Ἀχαιός : a
# τέτρατος : a
# ἔτος : d
# ἔρχομαι : v
# ὥρα : v
# ἐπέρχομαι : v
# γυνή : v
# οἶδα : v
# σάφα : d
# ἐφευρίσκω : v
# ἄγω : a
# ἀναλύω : v
# ἱστός : a
# ἀγλαός : a
# ἐκτελέω : v
# ἐθέλω : v
# ἀνάγκη : n
# Μνηστήρ : n
# ὑποκρίνομαι : v
# οἶδα : v
# θυμός : n
# Ἀχαιός : a
# οἶδα : v
# Ἀποπέμπω : n
# μήτηρ : n
# ἄνωγα : v
# γαμέω : v
# πατήρ : n
# κέλομαι : v
# ἁνδάνω : v
# ἀνιάω : v
# χρόνος : n
# υἱός : n
# Ἀχαιός : n
# φρονέω : v
# θυμός : n
# Ἀθήνη : n
# δίδωμι : v
# ἐπίστημι : v
# ἔργον : n
# περικαλλής : a
# φρήν : n
# ἐσθλός : a
# κέρδος : n
# ἀκούω : v
# παλαιός : a
# Ἀχαιός : a
# εὐπλοκαμίς : a
# Τυρός : n
# Ἀλκμήνη : n
# Μυκήνη : n
# εὐστέφανος : a
# οὔτις : a
# οἶδα : a
# νόημα : a
# ὅμοιος : a
# Πηνελόπεια : a
# νοέω : v
# ἐναίσιμος : a
# · : d
# ἔδω : v
# βίοτος : n
# κτῆμα : d
# νόος : n
# θεός : n
# τίθημι : n
# στῆθος : n
# μέγας : a
# κλέος : n
# σοίγε : a
# ποθή : n
# βίοτος : n
# ἔργον : d
# γαμέω : v
# Ἀχαιός : a
# ἐθέλω : v
# Τηλέμαχος : n
# πέπνυμαι : v
# αὐδάω : v
# ἀντίος : v
# Ἀντίνοος : v
# οὔπως : d
# ἀπωθέω : v
# δόμος : v
# ἀέκων : v
# τίκτω : v
# τρέφω : v
# πατήρ : -
# ἄλλοθι : d
# γαῖος : -
# ὅσε : p
# ζώω : v
# θνήσκω : v
# Κακός : n
# ἀποτίνω : v
# Ἰκάριος : a
# ἑκών : a
# ἀποπέμπω : v
# μήτηρ : n
# Πείδω : n
# κακός : a
# πατήρ : n
# δαίμων : n
# δίδωμι : v
# μήτηρ : n
# ἀράομαι : v
# Ἐρινύς : n
# στυγερός : a
# ἀπέρχομαι : v
# οἶκος : n
# νέμεσις : n
# ἄνθρωπος : n
# ἐνέπω : v
# μῦθος : n
# θυμός : n
# νεμεσίζομαι : v
# ἔξιτος : v
# μέγαρον : a
# ἀλεγύνω : v
# δαίς : n
# ἔδω : v
# κτῆμα : n
# ἀμείβω : v
# οἶκος : n
# δοκέω : v
# λωίων : a
# ἀμείνων : a
# ὄλλυμι : v
# νήποινος : a
# βίοτος : n
# εἷς : n
# ἀνήρ : n
# κείρω : v
# ἐπιβόω : v
# θεός : v
# Ζεύς : n
# δίδωμι : v
# ἔργον : n
# παλίντιτος : a
# ὄλλυμι : v
# νήποινος : a
# δόμος : n
# Τηλέμαχος : n
# · : -
# Ζεύς : n
# εὐρύοπα : a
# προίημι : v
# πέτομαι : v
# ἀετός : n
# ὑψόθεν : d
# κορυφή : n
# ὄρος : n
# πέτομαι : v
# πνοή : n
# ἄνεμος : n
# τιταίνω : v
# πτέρυξ : a
# πλησίος : a
# ἱκνέομαι : v
# μέσος : a
# ἀγορά : n
# πολύφημος : a
# ἐπιδινέω : v
# τινάσσω : v
# πτερόν : n
# εἰσοράτης : v
# κεφαλή : n
# ὄσσομαι : v
# ὄλεθρος : n
# δρύπτω : v
# ὄνυξ : n
# παρειά : n
# δειρή : n
# ἀίσσω : v
# δεξιός : a
# οἰκίον : n
# πόλις : n
# Θαμβέων : n
# ὄρνις : n
# εἶδον : v
# ὀφθαλμός : n
# ὁρμαίνω : v
# θυμός : n
# μέλλω : v
# τελέω : v
# μετεῖπον : v
# γέρων : n
# ἥρως : n
# Ἁλιθέρσης : n
# Μαστορίδης : n
# · : n
# καίκασα : v
# ὁμηλικία : n
# γιγνώσκω : v
# ὄρνις : v
# μυθέομαι : v
# ἐναίσιμος : a
# εὐφρονέων : v
# ἀγοράομαι : v
# μετεῖπον : v
# Κόκλυτος : n
# Ἰθακήσιος : a
# εἴρω : v
# πιφαύσκω : v
# μνηστήρ : n
# μέγας : a
# πῆμα : v
# κυλίνδω : v
# Ὀδυσσεύς : n
# φίλος : d
# φυτεύω : v
# φόνος : n
# κήρ : n
# · : d
# κακός : a
# νέμω : v
# Ἰθάκη : n
# εὐδείελος : a
# Ἀλλὰ : c
# φράζω : v
# καταπαύω : v
# παύω : v
# λωίων : a
# Μαντεύω : v
# ἀπείρητος : d
# οἶδα : v
# τελευτάω : v
# μυθέομαι : v
# Ἀργεῖος : a
# εἰσαναβαίνω : v
# Ἴλιος : a
# Ὀδυσσεύς : n
# πολύμητις : a
# βαίνω : v
# Φῆν : a
# πάσχω : v
# κακός : a
# ἀπόλλυμι : v
# ἑταῖρος : a
# ἄγνωστος : a
# ἔρχομαι : v
# εἰκοστός : a
# ἐνιαυτός : n
# Πᾶντα : n
# τελέω : v
# Εὐρύμαχος : n
# Πόλυβος : n
# αὐδάω : v
# γέρων : n
# μαντεύομαι : v
# τέκος : d
# πάσχω : v
# κακός : a
# ἀμείνων : a
# μαντεύομαι : v
# Ὄρνιθες : n
# φοιτάω : v
# αὐγή : n
# ἠέλιος : n
# ἐναίσιμος : a
# Ὀδυσσεύς : n
# ὄλλυμι : v
# ὀφείλω : v
# καταφθίω : v
# ἄν1 : d
# ἀγορεύω : v
# θεοπροπέω : v
# ἀνίημι : v
# Τηλέμαχος : n
# χολόω : v
# προσδέχομαι : v
# δῶρον : n
# οἶκος : n
# πόρω : v
# Ἀλλά : c
# ἐξερέω : v
# τελέω : v
# οἶδα : v
# παλαιός : a
# ἐποτρύνω : v
# χαλεπαίνω : v
# ἀνήρ : v
# νέος : a
# παράφημι : v
# ἔπος : v
# πρῶτος : a
# ἀνιαρός : a
# ἕ : d
# δύναμαι : v
# πρήσσω : v
# γέρων : -
# ἐπιτίθημι : v
# θωή : v
# τίνω : a
# ἀσχάλλω : v
# θυμός : n
# ἄλγος : n
# χαλεπός : a
# ὑποτίθημι : v
# Τηλέμαχος : n
# ἄνωγα : v
# μήτηρ : n
# ἀπονέομαι : v
# πατήρ : n
# τεύχω : v
# γάμος : n
# ἀρτύνω : v
# ἕδνον : n
# ἔοικα : v
# ἕπομαι : v
# φίλος : a
# οἴομαι : v
# υἱός : n
# Ἀχαιός : a
# παύω : v
# μνηστύς : a
# ἀργαλέος : a
# δείδω : v
# οὔτις : d
# Τηλέμαχος : d
# πολύμυθος : a
# ἐμπάζομαι : v
# θεοπροπία : a
# γεραιός : a
# μυθέομαι : a
# ἀκράαντος : a
# ἀπεχθάνομαι : a
# χρῆμα : n
# βιβρώσκω : v
# κακός : d
# ἴσος : d
# ὅγε : v
# διατρίβω : v
# Ἀχαιός : a
# γάμος : n
# προσδέχομαι : v
# ἦμαρ : v
# ἐριδαίνω : v
# ἀρετή : a
# ἔρχομαι : v
# ἐπιεικής : a
# ὀπυίω : v
# Τηλέμαχος : n
# πέπνυμαι : v
# αὐδάω : v
# ἀντίος : a
# Εὐρύμαχος : n
# μνηστήρ : a
# ἀγαυός : a
# λίσσομαι : v
# ἀγορεύω : v
# θεός : n
# Ἀχαιός : a
# οἶδα : v
# · : d
# δίδωμι : d
# ναῦς : n
# θοός : a
# εἴκοσι : a
# ἑταῖρος : n
# διαπράσσω : v
# κέλευθος : n
# Σπάρτη : n
# Πύλος : n
# ἠμαθόεις : a
# πυνθάνομαι : v
# νόστος : n
# πατήρ : n
# οἴχομαι : v
# βροτός : n
# ἀκούω : v
# Ζεύς : n
# ὅστε : p
# φέρω : v
# κλέος : n
# ἄνθρωπος : n
# ἀκούω : v
# βίοτος : n
# νόστος : n
# πατήρ : n
# τλάω : v
# ἄν1 : d
# ἐνιαυτός : d
# τρύχω : v
# ἀκούω : v
# θνήσκω : v
# νοστέω : v
# φίλος : a
# γαῖα : n
# πατρίς : n
# χέω : v
# σῆμα : n
# κτερείζω : v
# κτέρεα : n
# ἔοικα : v
# δίδωμι : v
# μήτηρ : n
# ἀνήρ : n
# ὅσγε : p
# καθέζομαι : v
# ἀνίστημι : v
# Μέντωρ : n
# ἑταῖρος : n
# ἀμύμων : a
# Ὀδυσσεύς : n
# ναῦς : n
# ἐπιτρέπω : v
# οἶκος : v
# πείθω : v
# γέρων : v
# φυλάσσω : v
# ἔμπεδος : a
# εὐφρονέων : v
# ἀγοράομαι : v
# μετεῖπον : v
# Κόκλυτος : n
# Ἰθακήσιος : a
# βασιλεύς : a
# σκηπτοῦχος : a
# πρόφρων : a
# ἀγανός : a
# ἤπιος : a
# οἶδα : v
# φρήν : n
# αἴσιμος : a
# χαλεπός : a
# ῥέζω : v
# αἴσυλος : a
# οὔτις : a
# λαός : a
# μιμνήσκω : v
# θεῖος : a
# Ὀδυσσεύς : a
# ἀνάσσω : v
# πατήρ : n
# ἤπιος : a
# Ἀλλά : c
# μεγαίρω : v
# μνηστήρ : n
# ἀγήνωρ : n
# ἔρδω : v
# ἔργον : n
# βίαιος : n
# κακορραφία : n
# νόος : n
# · : n
# παρθέω : v
# σφός : n
# κεφαλή : n
# κατέδω : v
# βίαιος : a
# οἶκος : n
# Ὀδυσσεύς : n
# νέομαι : v
# νεμεσίζομαι : v
# δῆμος : n
# ἧμαι : v
# ἄνεω : v
# κατερύκω : v
# καθάπτω : v
# ἔπος : n
# μνηστήρ : n
# παῦρος : a
# Λειώκριτος : n
# Εὐηνορίδης : n
# αὐδάω : v
# ἀντίος : a
# Μέντωρ : n
# ἀταρτηρός : a
# ἠλεός : a
# φρήν : n
# ὀτρύνω : v
# καταπαύω : v
# Ἀργαλέος : n
# ἀνήρ : n
# πλείων : a
# μάχομαι : v
# δαίς : n
# Ὀδυσσεύς : n
# Ἰθακήσιος : a
# ἐπέρχομαι : v
# μενοινάω : v
# θυμός : n
# ἐξελαύνω : v
# μέγαρον : n
# μνηστήρ : n
# ἀγαυός : v
# δαίνυμι : v
# δῶμα : v
# γυνή : n
# χατέω : v
# χαίρω : v
# ἕ : d
# ἔρχομαι : v
# ἐφέπω : v
# πότμος : a
# ἀεικής : a
# ἕπομαι : v
# πλείων : a
# μοῖρα : n
# Ἀλλά : c
# λαός : n
# σκίδνημι : v
# ἔργον : n
# Μέντωρ : n
# ὀτρύνω : v
# ὁδός : n
# Ἁλιθέρσης : n
# ὅστε : p
# ἀρχή : n
# ἑταῖρος : n
# πατρώιος : a
# Ἀλλά : c
# οἴομαι : v
# κάθημαι : v
# πυνθάνομαι : v
# ἀγγελία : v
# Ἰθάκη : n
# οὔποτε : d
# τελέω : v
# ὁδός : n
# φωνέω : v
# λύω : v
# ἀγορά : n
# αἰψηρός : a
# σκίδνημι : v
# δῶμα : n
# μνηστήρ : n
# οἶδα : v
# ἀραρίσκω : v
# τοῖχος : n
# Ὀδυσσεύς : n
# νοστέω : v
# μογέω : v
# ἄλγος : n
# Σανίδες : n
# κλειστός : n
# δικλίς : n
# ἀραρίσκω : v
# πυκνός : d
# ἔπειμι : v
# · : d
# νύξ : n
# ἦμαρ : n
# γυνή : n
# ταμία : n
# φυλάσσω : v
# πολυιδρεία : n
# νόος : n
# Εὐρύκλεια : n
# θυγάτηρ : n
# Ὤπος : n
# Πεισηνορίδης : n
# Τηλέμαχος : n
# πρόσφημι : v
# καλέω : v
# θάλαμόνδε : d
# Μαῖα : n
# ἄφυσσος : v
# ἀμφιφορεύς : n
# οἶνος : n
# ἡδύς : a
# λαρός : a
# φυλάσσω : v
# οἴομαι : v
# κάμμορος : a
# εἴποθεν : v
# ἔρχομαι : v
# Ὀδυσσεύς : n
# διογενής : a
# ἀλύσκω : v
# θάνατος : n
# κήρ : n
# ἐμπίπλημι : n
# δώδεκα : a
# ἀραρίσκω : n
# πῶμα : n
# Χεύω : n
# ἄλφιτον : n
# δορός : n
# ἐυρραφής : a
# εἴκοσι : a
# μέτρον : n
# ἀκτή : n
# ἄλφιτον : n
# μυλήφατος : a
# Ἴσθι : d
# τεύχω : v
# ἀθρόος : a
# αἱρέω : v
# ἑσπέριος : a
# μήτηρ : n
# ἀναβαίνω : v
# ὑπερῷον : n
# μέδομαι : n
# κοῖτος : n
# Σπάρτη : n
# Πύλος : n
# ἠμαθόεις : a
# πυνθάνομαι : v
# νόστος : n
# πατήρ : n
# φίλος : a
# ἀκούω : v
# Φάτος : n
# φίλος : a
# τροφός : n
# Εὐρύκλεια : n
# κωκύω : v
# ὀλοφύρομαι : v
# προσαυδάω : v
# ἔπος : n
# πτερόεις : a
# Τίπτε : d
# φίλος : a
# τέκνον : n
# νόημα : n
# πέλω : v
# φρήν : n
# πῆ : v
# ἐθέλω : v
# γαῖα : n
# μόνος : a
# ἀγαπητός : a
# Ὀδυσσεύς : n
# διογενής : a
# ὄλλυμι : v
# τηλόθι : d
# πάτρη : n
# δῆμος : n
# ἀλλόγνωτος : a
# φράζω : v
# κακός : d
# φθίω : v
# δόλος : a
# δατέομαι : v
# Ἀλλὰ : c
# μένω : v
# κάθημαι : v
# χρή : v
# πάσχω : v
# κακός : -
# ἀλαλήθω : v
# πόντος : n
# ἀτρύγετος : a
# Τηλέμαχος : n
# πέπνυμαι : v
# αὐδάω : v
# ἀντίος : a
# Θάρσοι : n
# μαῖα : n
# βουλή : n
# οὔτοι : d
# θεός : n
# Ἀλλὰ : c
# ὄμνυμι : v
# μυθέομαι : v
# μήτηρ : n
# φίλος : a
# ἄν1 : d
# ἑνδέκατος : a
# δωδέκατος : a
# ποθέω : v
# ἀκούω : v
# ἀφορμάω : v
# κλαίω : v
# κατιάπτω : v
# καλός : a
# χρώς : n
# Ἔφη : n
# γραῦς : n
# ἀπόμνυμι : n
# μέγας : a
# ὅρκος : n
# θεός : n
# ὄμος : v
# ἑλευτέω : v
# ὅρκος : n
# ἀφύσσω : v
# οἶνος : n
# ἀμφιφορεύς : n
# χέω : n
# ἄλφιτον : n
# δορός : n
# ἐυρραφής : a
# Τηλέμαχος : n
# δῶμα : n
# ὁμιλέω : n
# μνηστήρ : n
# θεά : n
# Ἀθήνη : n
# γλαυκῶπις : a
# νοέω : v
# · : d
# εἰκός : v
# Τηλέμαχος : n
# οἴχομαι : v
# πόλις : n
# παρίστημι : v
# φώς : n
# μῦθος : n
# ἄνωγα : v
# ἀγέρομαι : v
# ἑσπέριος : a
# ναῦς : n
# θοός : a
# αἰτέω : v
# ναῦς : n
# θοός : a
# Νοήμων : n
# υἱός : n
# φαίδιμος : a
# Φρόνιος : n
# ὑποδέχομαι : v
# πρόφρων : a
# ἠέλιος : n
# δύω : v
# ἀγυιά : a
# σκιάω : v
# ἐρύω : v
# ἅλαδε : d
# ναῦς : n
# θοός : a
# τίθημι : v
# ὅπλον : n
# τάτε : d
# φορέω : v
# ναῦς : n
# εὔσελμος : a
# ἵστημι : v
# ἐσχατιά : n
# λιμήν : n
# ἐσθλός : a
# ἑταῖρος : n
# ἠγερέθος : v
# ἀθρόος : a
# θεά : n
# ὀτρύνω : v
# θεά : n
# Ἀθήνη : n
# γλαυκῶπις : a
# νοέω : v
# · : n
# βαίνω : v
# δῶμα : n
# θεῖος : n
# Ὀδυσσεύς : n
# · : n
# ἐπιχέω : v
# μνηστήρ : n
# γλυκύς : a
# ὕπνος : n
# πλάζω : v
# πίνω : v
# ἐκβάλλω : v
# κύπελλον : n
# χείρ : n
# ὄρνυμι : v
# πόλις : n
# εὕδω : v
# ἕͅμα : v
# ὕπνος : n
# πίπτω : v
# βλέφαρον : n
# Ἀθήνη : n
# γλαυκῶπις : n
# πρόσφημι : v
# Τηλέμαχος : n
# ἐκπροκαλέω : v
# μέγαρον : n
# εὐναιετάω : v
# εἴδομαι : v
# Μέντωρ : n
# δέμας : n
# αὐδή : n
# Τηλέμαχος : n
# ἑταῖρος : n
# ἐυκνήμις : a
# ἧμαι : v
# ἐπήρετμος : a
# προσδέχομαι : v
# ὁρμή : n
# διατρίβω : v
# ὁδός : n
# Φωνέω : n
# Παλλάς : n
# Ἀθήνη : n
# ἡγέομαι : v
# καρπάλιμος : d
# · : d
# βαίνω : v
# ἴχνιον : n
# θεός : n
# κατέρυθος : v
# ναῦς : n
# θάλασσα : n
# εὑρίσκω : v
# θίς : n
# ἑταῖρος : n
# καρηκομάω : v
# ἴς : n
# ἱερός : a
# Τηλέμαχος : n
# μετεῖπον : v
# Δεῦτε : n
# φίλος : a
# φέρω : v
# ἤια : a
# ἀθρόος : a
# μέγαρον : n
# μήτηρ : n
# πύσσα : v
# δμωή : n
# εἷς : a
# ἀκούω : v
# μῦθος : n
# Φωνέω : v
# ἡγέομαι : v
# ἕπομαι : v
# φέρω : v
# κατατίθημι : v
# ναῦς : n
# εὔσελμος : a
# υἱός : n
# φίλος : a
# Ὀδυσσεύς : n
# κελεύω : v
# Τηλέμαχος : n
# ἀναβαίνω : v
# ναῦς : n
# Ἀθήνη : n
# ἄρχω : v
# Πρώτιστος : n
# ὀπάζω : v
# κῦδος : n
# Νέστωρ : n
# υἱός : n
# · : n
# δίδης : n
# Πύλιος : n
# σύμπας : a
# ἀμοιβή : n
# χαρίεις : a
# ἑκατόμβη : n
# ἀγακλειτός : a
# Δόος : n
# Τηλέμαχος : n
# νέομαι : v
# πράσσω : v
# ἱκνέομαι : v
# ναῦς : n
# θοός : a
# μέλας : a
# ὀράομαι : v
# τελευτάω : v
# δίδωμι : v
# Τηλέμαχος : n
# καλός : a
# δέπας : n
# ἀμφικύπελλος : a
# υἱός : n
# φίλος : n
# Ὀδυσσεύς : n
# ἀράομαι : v
# ὀπτάω : v
# ἐρύω : v
# κρέας : n
# ὑπέρτερος : a
# δατέομαι : v
# μοῖρα : n
# δαίνυμι : v
# δαίς : n
# ἐρικυδής : a
# ἔξεστι : v
# ἔρος : n
# πόσις : n
# ἐδητύς : n
# Νέστωρ : n
# Γερήνιος : n
# ἱππότης : n
# ἄρχω : v
# μῦθος : n
# καλός : v
# μεταλλάω : v
# ἔρομαι : v
# ξένος : a
# τέρπω : v
# ἐδωδή : n
# ξένος : n
# πλέω : a
# κέλευθος : n
# ὑγρός : n
# πρᾶξις : n
# ἀλάλημαι : v
# ἅλς : n
# μαψίδιος : d
# λῃστήρ : a
# ἀλάομαι : v
# παρατίθημι : v
# ψυχή : a
# φέρω : v
# κακός : a
# ἀλλοδαπός : a
# Τηλέμαχος : n
# πέπνυμαι : v
# αὐδάω : v
# ἀντίος : v
# θαρσέω : v
# · : v
# Ἀθήνη : n
# τίθημι : v
# θάρσος : n
# φρήν : n
# ἔρομαι : v
# πατήρ : n
# ἀποίχομαι : v
# κλέος : n
# ἐσθλός : a
# ἄνθρωπος : n
# Νέστωρ : n
# Νηληιάδης : n
# μέγας : a
# κῦδος : n
# Ἀχαιός : n
# ἔρομαι : v
# ὁπόθεν : d
# καταλέγω : v
# ἔρχομαι : v
# Ἰθάκη : n
# Ὑπονήιος : a
# πρᾶξις : n
# ἀγορεύω : v
# ἴδιος : a
# δήμιος : a
# Μετέρχομαι : n
# κλέος : n
# εὐρύς : a
# πατήρ : n
# ἀκούω : v
# δῖος : v
# Ὀδυσσεύς : n
# ταλασίφρων : a
# μάρναμαι : v
# ἐξαλαπάζω : v
# πόλις : n
# Τρώς : n
# Πεύθω : v
# πολεμίζω : v
# Τρώς : a
# ἧχι : a
# ἀπόλλυμι : v
# ὄλεθρος : a
# λυγρός : a
# Κρονίων : a
# τίθημι : v
# ὄλεθρος : a
# ἀπευθής : a
# δύναμαι : v
# ὁπόθι : d
# ὄλλυμι : v
# ὅσγε : d
# δαμά : v
# ἤπειρος : n
# ἀνήρ : n
# δυσμενής : a
# πέλαγος : n
# κῦμα : n
# Ἀμφιτρίτη : n
# Τούνεκα : d
# ἱκάνω : v
# γόνυ : v
# ἐθέλω : v
# ἐνέπω : v
# ὄλεθρος : v
# λυγρός : a
# ὁράω : v
# ὀφθαλμός : n
# ἀκούω : v
# μῦθος : n
# πλάζω : v
# μήτηρ : n
# τίκτω : v
# ὀιζυρός : a
# Μηδέ : c
# μειλίσσω : v
# αἰδέομαι : v
# ἐλεαίρω : v
# καταλέγω : v
# ἀντάω : v
# ὀπωπή : n
# Λίσσομαι : n
# πατήρ : n
# ἐσθλός : a
# Ὀδυσσεύς : n
# ἐκτελέω : v
# ἔπος : n
# ἔργον : n
# ὑφίστημι : v
# δῆμος : n
# Τρώς : n
# Ἀχαιός : n
# πάσχω : v
# πῆμα : n
# μιμνήσκω : v
# ἐνέπω : v
# νημερτής : a
# Νέστωρ : n
# Γερήνιος : a
# ἱππότης : n
# ἀμείβω : v
# φίλος : a
# μιμνήσκω : v
# ὀιζύς : n
# ἀνατλῆναι : v
# δῆμος : n
# υἱός : n
# Ἀχαιός : a
# ἄσχετος : a
# μένος : n
# μάρναμαι : v
# πλάζω : v
# ναῦς : n
# πόντος : n
# ἠεροειδής : a
# ληίς : n
# ὅπη : d
# ἄρχω : v
# Ἀχιλλεύς : n
# ἄστυ : n
# μέγας : a
# Πρίαμος : n
# ἄναξ : n
# · : d
# κατακτείνω : v
# ἄριστος : a
# · : d
# κεῖμαι : d
# Αἴας : n
# ἄρειος : a
# Ἀχιλλεύς : n
# Πάτροκλος : n
# μήστωρ : n
# ἀτάλαντος : a
# θεόφιν : n
# υἱός : n
# φίλος : a
# κρατερός : a
# ἀμύμων : a
# Ἀντίλοχος : a
# ταχύς : a
# θέω : -
# μαχητής : a
# πάσχω : v
# κακός : a
# ἄνθρωπος : a
# καταθνητός : a
# μυθέομαι : a
# ; : d
# παραμίμνω : a
# πενταετής : a
# ἑξαετής : a
# ἐξερέω : a
# κακός : a
# δῖος : a
# Ἀχαιός : a
# πάσχω : v
# ἀνιάω : v
# ἱκνέομαι : v
# γαῖα : n
# πατρίς : a
# Εἰναετής : n
# ῥάπτω : v
# κακός : a
# ἀμφιέπω : v
# δόλος : n
# παντοῖος : a
# Κρονίων : n
# τελέω : v
# μόγις : d
# οὔτις : a
# ἐθέλω : v
# ὁμοιόω : v
# ἄντην : d
# μῆτις : n
# δῖος : a
# Ὀδυσσεύς : n
# νικάω : v
# δόλος : a
# παντοῖος : a
# πατήρ : n
# ἐτεός : a
# ἔκγονος : a
# Σέβης : n
# εἰσοράω : v
# μῦθος : v
# ἔοικα : v
# ἀνήρ : v
# νέος : v
# μυθέομαι : v
# ἔοικα : v
# δῖος : d
# Ὀδυσσεύς : n
# βάζω : v
# δίχα : d
# ἀγορά : n
# βουλή : n
# εἷς : n
# θυμός : n
# φράζω : v
# νόος : n
# βουλή : n
# ἐπίφρων : a
# ὄχα : d
# ἄριστος : a
# Ἀργεῖος : a
# διαπέρω : v
# πόλις : n
# αἰπός : n
# Πρίαμος : n
# βαίνω : v
# ναῦς : n
# θεός : n
# κεδάννυμι : v
# Ἀχαιός : a
# Ζεύς : n
# μήδομαι : v
# φρήν : n
# νόστος : n
# λυγρός : a
# Ἀργεῖος : a
# νοήμων : a
# δίκαιος : a
# ἐφέπω : a
# οἶτος : a
# κακός : a
# μῆνις : a
# ὀλοός : a
# Γλαυκῶπις : n
# οβριμοπάτρη : n
# ὅστε : a
# τίθημι : v
# ἔρις : n
# Ἀτρείδης : n
# καλέω : v
# ἀγορά : n
# Ἀχαιός : n
# μάψ : d
# κόσμος : n
# ἠέλιος : n
# καταδύω : v
# υἱός : n
# ...
# Ἀλλά : c
# νόστος : n
# ̆ : c
# φαίνω : v
# ἀπήμων : a
# θεός : n
# στρέφω : v
# οὖρος : n
# ἱκνέομαι : v
# ἐσχατιά : n
# ἀγρός : n
# Θυέστης : n
# ναίω : v
# δῶμα : n
# ναίω : v
# Αἴγισθος : n
# Θυεστιάδης : n
# χαίρω : v
# ἐπιβαίνω : v
# αἶα : n
# πατρίς : n
# κύων : v
# ἅπτω : v
# πατρίς : a
# δάκρυον : n
# θερμός : a
# χέω : v
# εἶδον : d
# γαῖα : n
# ἀσπάσιος : d
# Σκοπός : n
# εἶδον : v
# σκοπιά : n
# Αἴγισθος : n
# δολομήτης : n
# καθίζω : v
# ἄγω : v
# ὑπισχνέομαι : v
# μισθός : n
# δοιοί : n
# τάλαντον : n
# χρυσός : n
# ὅσγε : p
# φυλάσσω : v
# ἐνιαυτός : n
# λανθάνω : v
# ἕ : p
# πάρειμι : v
# μιμνήσκω : v
# θοῦρις : n
# ἀλκή : n
# βαίνω : v
# δῶμα : n
# ἀγγέλλω : v
# ποιμήν : n
# λαός : n
# Αὐτίκα : d
# Αἴγισθος : n
# ̆ : c
# φράζω : v
# τέχνη : n
# δόλιος : a
# κρίνω : v
# δῆμος : n
# ̆ : r
# εἴκοσι : a
# φώς : n
# ἄριστος : a
# ἵζω : v
# λόχος : n
# ἑτέρωθι : d
# ἄνωγα : v
# πένομαι : v
# δαίς : n
# βαίνω : v
# καλέω : v
# Ἀγαμέμνων : n
# ποιμήν : n
# λαός : n
# ἵππος : n
# ὄχος : n
# μερμηρίζω : v
# ἀεικής : a
# Ἀνάγω : n
# οἶδα : v
# ὄλεθρος : n
# κατέπεφνον : v
# δειπνίζω : v
# κατακτείνω : v
# βοῦς : n
# φάτνη : n
# ἑταῖρος : n
# Ἀτρείδης : n
# ἕπομαι : v
# Αἴγισθος : n
# λείπω : v
# κτείνω : v
# μέγαρον : n
# Ἔφη : v
# φίλος : a
# ἦτορ : n
# κατακλάω : v
# κλαίω : v
# κάθημαι : v
# ψάμαθος : v
# κῆρ : n
# ἐθέλω : v
# ζώω : v
# ὁράω : v
# φάος : n
# ἠέλιος : n
# κορέννυμι : v
# κλαίω : v
# κυλίνδω : v
# γέρων : a
# ἅλιος : a
# νημερτής : a
# προσεῖπον : v
# Υἱός : n
# Ἀτρεύς : n
# κλαίω : v
# ̆ : c
# χρόνος : n
# ἀσκελής : a
# δήω : v
# ἄνυσις : n
# πείρω : a
# ταχύς : a
# ἱκνέομαι : n
# γαῖα : n
# πατρίς : n
# κιχάνω : v
# ζωός : a
# Ὀρέστης : n
# κτείνω : v
# ὑποφθάνω : v
# ἀντιβολέω : v
# τάφος : n
# Ἔφη : n
# καρδία : n
# θυμός : n
# νέος : a
# ἐξοίχομαι : v
# ἐρύω : v
# ναῦς : n
# κρίνω : v
# δῆμος : n
# ἄριστος : a
# Ἄρξος : n
# κακός : a
# Ζεύς : n
# ὄλλυμι : v
# βία : n
# φυτεύω : v
# πῆμα : n
# Ἀλλὰ : c
# δίδωμι : v
# ναῦς : n
# θοός : a
# εἴκοσι : a
# ἑταῖρος : n
# λοχέω : v
# φυλάσσω : v
# πορθμός : n
# Ἰθάκη : n
# Σάμος : n
# παιπαλόεις : a
# ναυτίλλομαι : v
# ἄν1 : d
# ἐπισμυγερός : d
# πατήρ : n
# Ἔφη : v
# ἐπαινέω : v
# κελεύω : v
# ἀνίστημι : v
# βαίνω : v
# δόμος : n
# Ὀδυσσεύς : n
# Πηνελόπεια : n
# χρόνος : n
# ἄπυστος : a
# μῦθος : n
# μνηστήρ : n
# βυσσοδομεύω : v
# φρήν : n
# · : n
# κῆρυξ : n
# Μέδων : n
# πεύθω : v
# βουλή : n
# αὐλή : n
# ἔνδοθι : d
# ὑφαίνω : v
# μῆτις : n
# βαίνω : v
# δῶμα : n
# ἀγγέλλω : v
# Πηνελόπεια : n
# Πηνελόπεια : n
# προσαυδάω : v
# βαίνω : v
# οὐδός : n
# Κῆρυξ : n
# τίπτε : p
# μνηστήρ : n
# ἀγαυός : a
# πρόειμι : v
# ; : v
# δμωή : n
# θεῖος : v
# Ὀδυσσεύς : n
# παύω : v
# ἔργον : n
# πένομαι : v
# δαίς : n
# μνηστεύω : v
# ὁμιλέω : v
# δειπνέω : v
# ὕστερος : a
# πύματος : a
# ἀγείρω : v
# θαμά : a
# κατακείρω : v
# βίοτος : n
# κτῆσις : n
# δαίφρων : a
# Τηλέμαχος : n
# ἀκούω : v
# πατήρ : v
# Ὀδυσσεύς : n
# τοκεύς : v
# ῥέζω : v
# ἐξαίσιος : a
# δῆμος : n
# ἐχθαίρω : a
# βροτός : n
# φιλέω : a
# δίκη : n
# ὅστε : p
# βασιλεύς : a
# θεῖος : a
# οὔποτε : d
# ἔρδω : v
# ἀτάσθαλος : a
# ἀνήρ : n
# Ἀλλά : c
# θυμός : n
# ἔργον : n
# ἀεικής : a
# φαίνω : v
# χάρις : n
# εὐεργής : a
# Μέδων : v
# οἶδα : v
# πέπνυμαι : v
# προσεῖπον : v
# Αἴ : d
# βασίλεια : a
# κακός : a
# πλεῖστος : a
# Ἀλλὰ : a
# μνηστήρ : a
# φράζω : v
# μέγας : a
# ἀργαλέος : a
# τελέω : v
# Κρονίων : a
# · : a
# μέμαα : v
# κατακτείνω : v
# χαλκός : n
# ὀξύς : a
# Τηλέμαχος : n
# νίσσομαι : v
# · : n
# βαίνω : v
# ἀκουή : n
# πατήρ : n
# Πύλος : n
# ἠγάθεος : a
# δῖος : a
# Λακεδαίμων : n
# Φῆτος : d
# λύω : v
# γόνυ : n
# ἦτορ : n
# φίλος : n
# ἀμφασία : n
# ἔπος : n
# λαμβάνω : v
# ὄσσε : n
# πίμπλημι : n
# δάκρυον : n
# φωνή : n
# θαλερός : a
# Ὀψέ : d
# ἀμείβω : v
# ἔπος : v
# προσεῖπον : v
# Κῆρυξ : n
# τίπτε : p
# οἴχομαι : v
# χρεώ : p
# ἐπιβαίνω : v
# ναῦς : n
# ὠκύπορος : n
# ὅστε : p
# ἀνήρ : n
# ἵππος : n
# ἅλς : n
# περάω : v
# ὑγρός : a
# ὄνομα : n
# λείπω : v
# ἄνθρωπος : n
# Μέδων : v
# οἶδα : v
# πέπνυμαι : v
# ἀμείβω : v
# οἶδα : v
# θεός : n
# ὄρος : v
# θυμός : n
# ἐφορμή : v
# Πύλος : n
# πυνθάνομαι : v
# νόστος : n
# πατήρ : n
# πότμος : n
# ἐφέπω : v
# Φωνέω : v
# ἀποβαίνω : v
# δῶμα : n
# Ὀδυσσεύς : n
# ἄχος : n
# θυμοφθόρος : a
# ἀμφιχέω : v
# τλάω : v
# ἐφέζομαι : v
# δίφρος : n
# οἶκος : v
# ἵζω : v
# οὐδός : n
# θάλαμος : n
# πολύκμητος : a
# ὀλοφύρομαι : v
# οἰκτρός : a
# μινυρίζω : v
# δμωή : n
# δῶμα : n
# νέος : a
# παλαιός : a
# Γοόωσα : v
# ἀδινός : a
# Πηνελόπεια : n
# μεταυδάω : v
# Κλῦτος : n
# φίλος : a
# Ὀλύμπιος : a
# δίδωμι : v
# ἄλγος : a
# τρέφω : v
# ἀπόλλυμι : v
# ἐσθλός : a
# πόσις : n
# θυμολέων : a
# ἀρετή : n
# παντοῖος : a
# Δαναός : n
# ἐσθλός : a
# κλέος : n
# εὐρύς : a
# Ἑλλάς : n
# μέσος : a
# Ἄργος : n
# · : n
# θύελλα : n
# ἀνερείπομαι : v
# μέγαρον : n
# ἀκλεής : n
# ἀγαπητός : a
# ἀκούω : v
# ὁρμάω : v
# Σχέτλιος : a
# τίθημι : v
# φρήν : n
# ἀνεγείρω : v
# λέχος : n
# ἐπίσταμαι : v
# σάφα : d
# θυμός : n
# βαίνω : v
# ναῦς : n
# κοῖλος : a
# μέλας : a
# πυνθάνομαι : v
# ὁρμαίνω : v
# ὁδός : d
# μένω : v
# ἐσσύμενος : v
# ὁδός : v
# λείπω : v
# θνήσκω : v
# μέγαρον : n
# Ἀλλά : a
# ὀτρηρός : d
# καλέω : v
# γέρων : n
# Δολίος : n
# δμώς : n
# πατήρ : n
# δίδωμι : v
# κίω : v
# κῆπος : v
# πολύδενδρος : a
# ταχύς : a
# παρέζομαι : v
# Λαέρτης : v
# καταλέγω : v
# ὑφήνη : v
# μῆτις : n
# φρήν : n
# ἐξέρχομαι : v
# ὀδύρομαι : v
# λαός : n
# μέμαα : v
# φθίω : v
# γόνος : n
# Ὀδυσσεύς : n
# ἀντίθεος : a
# Φίλος : n
# τροφός : n
# Εὐρύκλεια : n
# προσεῖπον : v
# Φίλος : n
# νύμφη : n
# κατακτένω : a
# χαλκός : n
# νηλής : a
# ἐάω : -
# μέγαρον : n
# ἐπικεύθω : v
# μῦθος : n
# οἶδα : v
# πόρος : n
# κελεύω : v
# σῖτος : n
# μέθυ : n
# ἡδύς : a
# αἱρέω : v
# μέγας : a
# ὅρκος : v
# δωδέκατος : a
# ποθέω : v
# ἀκούω : v
# ἀφορμάω : v
# ἄν1 : d
# κλαίω : v
# κατιάπτω : v
# καλός : a
# χρώς : n
# Ἀλλὰ : c
# ὑδραίνω : v
# αἱρέω : v
# χρώς : n
# εἷμα : n
# καθαρός : a
# ἀναβαίνω : v
# ὑπερῷον : n
# γυνή : n
# ἀμφίπολος : n
# εὔχομαι : v
# Ἀθήνη : n
# κόρη : n
# Ζεύς : n
# αἰγίοχος : a
# σώζω : v
# θάνατος : n
# Μηδέ : n
# κακόω : v
# γέρων : n
# κακόω : v
# · : v
# οἴομαι : v
# γονή : n
# Ἀρκεισιάδης : n
# ἔχθω : v
# θεός : n
# μάκαρ : n
# ἔπειμι : v
# δῶμα : n
# ὑψερεφής : a
# ἀγρός : n
# πίων : a
# ἀπόπροθι : d
# φῆμος : d
# εὐνάω : v
# γόος : n
# ὄσσε : n
# γόος : n
# ὑδραίνω : v
# αἱρέω : v
# χρώς : n
# εἷμα : n
# καθαρός : a
# ἀναβαίνω : v
# ὑπερῷον : n
# γυνή : n
# ἀμφίπολος : n
# ἐντίθημι : v
# κάνεον : n
# οὐλοχύται : n
# ἀράομαι : v
# Ἀθήνη : n
# Κλῦθις : n
# Ἀτρυτώνη : n
# τέκος : n
# Ζεύς : n
# αἰγίοχος : a
# Ὀδυσσεύς : n
# πολύμητις : n
# κατακαίω : n
# μέγαρον : n
# πίων : n
# μηρία : n
# βοῦς : n
# ὄις : n
# μιμνήσκω : v
# σῴον : n
# φίλος : a
# υἱός : n
# ἀπάλαλκε : v
# μνηστήρ : n
# ὑπερηνορέων : a
# κακός : d
# ὀλολύζω : v
# θεά : n
# κλύω : v
# ἀρή : n
# Μνηστήρ : n
# ὁμαδέω : v
# μέγαρον : n
# σκιόεις : a
# νέος : a
# ὑπερηνορέων : a
# βασίλεια : n
# πολυμνήστη : a
# ἀρτύω : v
# γάμος : n
# οἶδα : v
# φόνος : n
# τεύχω : v
# υἱός : n
# οἶδα : v
# τεύχω : v
# Ἀντίνοος : n
# ἀγοράομαι : v
# μετεῖπον : v
# δαιμόνιος : n
# ἀλέω : v
# μῦθος : n
# ὑπερφίαλος : a
# ἀπαγγέλλω : v
# Ἀλλὰ : c
# ἀνίστημι : v
# τελέω : v
# σιγή : v
# μῦθος : n
# ἀραρίσκω : v
# φρήν : n
# κρίνω : v
# εἴκοσι : v
# φώς : n
# ἄριστος : a
# · : n
# βαίνω : v
# ναῦς : n
# θοός : n
# θίς : n
# θάλασσα : n
# Πάμπρωτος : n
# ἐρύω : v
# ναῦς : n
# βένθος : d
# ἅλς : n
# τίθημι : v
# ναῦς : n
# μέλας : a
# ἱστός : n
# ἱστίον : n
# ἀρτύνω : v
# ἐρετμός : n
# τροπός : n
# δερμάτινος : a
# μοῖρα : n
# ἀναπετάζω : v
# ἱστίον : n
# λευκός : n
# θεράπων : n
# ὑπέρθυμος : a
# φέρω : v
# τεῦχος : n
# ὁρμίζω : n
# τένδω : p
# ὑψός : d
# νότιος : a
# ἐκβαίνω : v
# αἱρέω : v
# δόρπον : v
# μένω : v
# ἕσπερος : a
# ἐπέρχομαι : v
# περίφρων : a
# Πηνελόπεια : n
# κεῖμαι : v
# ὑπερῷον : n
# ἄσιτος : a
# ἄπαστος : a
# ἐδητύς : n
# ποτής : n
# ὁρμαίνω : v
# υἱός : n
# ἀμύμων : a
# φεύγω : v
# θάνατος : n
# ὅσγε : p
# δαμάζω : v
# μνηστήρ : n
# ὑπερφίαλος : a
# μερμηρίζω : v
# λέων : n
# ὅμιλος : n
# ἀνήρ : n
# δείδω : v
# περιάγω : v
# κύκλος : n
# δόλιος : a
# νήδυμος : a
# ὕπνος : n
# ἐπέρχομαι : v
# ὁρμαίνω : v
# εὕδω : v
# ἀνακλίνω : v
# ἅψος : p
# λύω : v
# θεά : n
# Ἀθήνη : n
# γλαυκῶπις : a
# νοέω : v
# εἴδωλον : n
# ἔοικα : v
# δέμας : n
# γυνή : n
# Ἰφθίμη : n
# κόρη : n
# μεγαλήτωρ : n
# Ἰκάριος : n
# ὀπυίω : v
# Εὔμηλος : n
# ναίω : v
# οἰκίον : n
# Φεραί : n
# πέμπω : n
# δῶμα : n
# θεῖος : a
# Ὀδυσσεύς : n
# παύω : v
# κλαυθμός : n
# γόος : n
# τέτε : d
# δακρυόεις : a
# Πηνελόπεια : n
# ὀδύρομαι : v
# γοάω : v
# Εἰσέρχομαι : n
# θάλαμος : n
# ἱμάς : n
# κλείς : n
# ἵστημι : v
# κεφαλή : n
# προσεῖπον : v
# μῦθος : n
# Εὕδης : n
# Πηνελόπεια : n
# τετίημαι : v
# φίλος : n
# ἦτορ : n
# θεός : n
# ζώω : v
# ῥεῖα : d
# ἐάω : v
# κλαίω : v
# ἀχεύω : v
# νόστιμος : d
# ἀλιτάω : v
# θεός : n
# Περίφρων : n
# Πηνελόπεια : n
# κνώσσω : v
# ἡδύς : a
# πύλη : n
# ὀνείρειος : n
# ἀμείβω : v
# Τίπτε : d
# κασιγνήτη : n
# ἔρχομαι : v
# πωλέομαι : v
# ναίω : v
# δῶμα : n
# ἀπόπροθι : d
# · : d
# κέλομαι : v
# παύω : v
# ὀιζύς : n
# ὀδύνη : a
# ἐρέθω : v
# φρήν : n
# θυμός : n
# ἀπόλλυμι : v
# ἐσθλός : a
# πόσις : n
# θυμολέων : a
# ἀρετή : n
# παντοῖος : a
# Δαναός : n
# ἐσθλός : a
# κλέος : n
# εὐρύς : a
# Ἑλλάς : n
# μέσος : a
# Ἄργος : n
# ἀγαπητός : a
# βαίνω : n
# ναῦς : n
# κοῖλος : a
# νήπιος : a
# οἶδα : n
# πόνος : n
# ἀγορά : a
# ὀδύρομαι : v
# ἤπερ : d
# ἀμφιτρομέω : v
# δείδω : v
# πάσχω : v
# ὅσε : d
# δῆμος : n
# οἴχομαι : v
# πόντος : n
# δυσμενής : a
# μηχανάομαι : v
# ἵημι : v
# κτείνω : v
# ἱκνέομαι : v
# γαῖα : n
# πατρίς : n
# Εἴδωλος : n
# ἀμαυρός : a
# ἀπαμείβομαι : v
# πρόσφημι : v
# Θάρσοι : n
# δείδω : d
# φρήν : n
# πομπός : n
# ἕπομαι : v
# ἀνήρ : v
# ἀράομαι : v
# παρίστημι : v
# δύναμαι : v
# Παλλάς : v
# Ἀθήνη : v
# ἐλεαίρω : v
# ὀδύρομαι : v
# προίημι : v
# μυθέομαι : v
# Περίφρων : n
# Πηνελόπεια : n
# προσεῖπον : v
# θεός : n
# κλύω : v
# αὐδή : n
# θεός : n
# καταλέγος : v
# ὀιζυρός : a
# ζώω : v
# ὁράω : v
# φάος : n
# ἠέλιος : v
# θνήσκω : v
# δόμος : n
# ᾍδης : n
# Εἴδωλος : n
# ἀμαυρός : a
# ἀπαμείβομαι : v
# πρόσφημι : v
# ἀγορεύω : v
# διηνεκής : d
# ὅσε : d
# ζώω : v
# θνήσκω : v
# κακός : a
# βάζω : v
# ἀνεμώλιος : a
# ἰπός : n
# λιάζομαι : v
# κλείς : n
# σταθμός : n
# πνοή : n
# ἄνεμος : n
# · : n
# κόρη : n
# Ἰκάριος : n
# ἀνορούω : v
# ὕπνος : n
# ἦτορ : n
# φίλος : n
# ἰαίνω : v
# ὄνειρος : n
# ἐναργής : a
# ἐπισεύω : v
# ἀμολγός : n
# νύξ : n
# Μνηστήρ : n
# ἀναβαίνω : v
# ἐπιπλέω : v
# κέλευθος : n
# ὑγρός : n
# ὁρμαίνω : v
# φρήν : n
# φόνος : n
# αἰπύς : a
# Τηλέμαχος : n
# νῆσος : n
# πετρήεις : a
# μέσος : a
# ἅλς : n
# μεσηγύ : a
# Ἰθάκη : n
# Σάμος : n
# παιπαλόεις : a
# Ἀστερίς : a
# μέγας : a
# λιμήν : a
# ναύλοχος : a
# ἀμφίδυμος : a
# Ἀχαιός : a
# λοχάω : v
# μένω : v
# ὅσγε : a

# %% [markdown]
# <h2>In case of already tagged Greek texts in XML, like in Perseus treebank</h2>

# %%
tree_grec=et.parse("./txts/odyssey_gk/odyssey_gk.xml")

# %%
gk_lemmatized_sentences = []
for p in tree_grec.findall(".//sentence"):
    sentence=[]
    for word in p.findall(".//word"):
        if "lemma" in word.attrib:
            if word.attrib["lemma"]!=" " and word.attrib["lemma"] not in stopwords_gk_combined and word.attrib["lemma"]!="" and word.attrib["form"] not in string.punctuation:
                sentence.append(word.attrib["lemma"])
    gk_lemmatized_sentences.append(sentence)

# %% [markdown]
# <h2>Checking sentences</h2>

# %%
print("lemmatized sentences in Greek : "+str(len(gk_lemmatized_sentences)))
print("lemmatized sentences in French : "+str(len(fr_lemmatized_sentences)))

# %% [markdown]
# <h2>Building French and Greek separate models with GloVe</h2>

# %% [markdown]
# glove_xx.model are glove basic models
# <br>glove_xx_compat.model are w2v compatible models

# %%
with open('gk_lemma_sentences.txt', 'w') as tmp_file:
    for sent in gk_lemmatized_sentences:
        tmp_file.write(" ".join(sent))
        tmp_file.write("\n")
    tmp_file.close()

# %%
corpus_fr = Corpus()
corpus_gk = Corpus()

# %%
dimensions=300

# %%
corpus_fr.fit(fr_lemmatized_sentences, window=20)
corpus_gk.fit(gk_lemmatized_sentences, window=20)

# %%
glove_fr = Glove(no_components=dimensions, learning_rate=0.05)
glove_fr.fit(corpus_fr.matrix, epochs=100, no_threads=4, verbose=False)
glove_fr.add_dictionary(corpus_fr.dictionary)
glove_fr.save('glove_fr.model')

# %%
glove_gk = Glove(no_components=dimensions, learning_rate=0.05)
glove_gk.fit(corpus_gk.matrix, epochs=100, no_threads=4, verbose=False)
glove_gk.add_dictionary(corpus_gk.dictionary)
glove_gk.save('glove_gk.model')

# %%
with open("glove_fr_compat.model", "w") as f:
    f.write(str(len(glove_fr.dictionary))+" "+str(dimensions)+"\n")
    for word in glove_fr.dictionary:
        f.write(word)
        f.write(" ")
        for i in range(0, dimensions):
            f.write(str(glove_fr.word_vectors[glove_fr.dictionary[word]][i]))
            f.write(" ")
        f.write("\n")

# %%
with open("glove_gk_compat.model", "w") as f:
    f.write(str(len(glove_gk.dictionary))+" "+str(dimensions)+"\n")
    for word in glove_gk.dictionary:
        f.write(word)
        f.write(" ")
        for i in range(0, dimensions):
            f.write(str(glove_gk.word_vectors[glove_gk.dictionary[word]][i]))
            f.write(" ")
        f.write("\n")

# %% [markdown]
# <h2>Loading saved (KeyedVectors) models</h2>

# %%
fr_glove_w2v = KeyedVectors.load_word2vec_format("glove_fr_compat.model", binary=False)
# Out:
# 2021-03-25 13:57:41,166 : loading projection weights from glove_fr_compat.model
# 2021-03-25 13:57:42,177 : loaded (3757, 300) matrix from glove_fr_compat.model

# %%
gk_glove_w2v = KeyedVectors.load_word2vec_format("glove_gk_compat.model", binary=False)
# Out:
# 2021-03-25 13:57:45,936 : loading projection weights from glove_gk_compat.model
# 2021-03-25 13:57:47,533 : loaded (5465, 300) matrix from glove_gk_compat.model

# %% [markdown]
# <h2>Some basic testing</h2>

# %%
fr_glove_w2v.most_similar("mer")
# Out:
# 2021-03-25 13:57:51,813 : precomputing L2-norms of word weight vectors
# [('houleux', 0.8846842050552368),
#  ('poissonneux', 0.814602255821228),
#  ('bord', 0.7764552235603333),
#  ('infécond', 0.7603996992111206),
#  ('rivage', 0.6789284944534302),
#  ('abîme', 0.6311653852462769),
#  ('sable', 0.6259430646896362),
#  ('niveau', 0.6209617853164673),
#  ('ensevelir', 0.6135373711585999),
#  ('emporter', 0.5914698243141174)]

# %%
gk_glove_w2v.most_similar("θάλασσα")
# Out:
# [('θίς', 0.9422957897186279),
#  ('ῥηγμίν', 0.9198570847511292),
#  ('κατέρχομαι', 0.9110517501831055),
#  ('πολύφλοισβος', 0.8878035545349121),
#  ('περάω', 0.7857462167739868),
#  ('βένθος', 0.7740625143051147),
#  ('νῶτον', 0.7571288347244263),
#  ('κλύζω', 0.7432551980018616),
#  ('ἐπελαύνω', 0.7122951745986938),
#  ('Ἀϊδόσδε', 0.7113521695137024)]

# %% [markdown]
# <h2>Saving models for MUSE</h2>

# %%
with open("glove_gk_muse.model", "w") as f:
    f.write(str(len(glove_gk.dictionary))+" "+str(dimensions)+"\n")
    for word in glove_gk.dictionary:
        f.write(word)
        f.write(" ")
        for i in range(0, dimensions):
            f.write(str(glove_gk.word_vectors[glove_gk.dictionary[word]][i]))
            f.write(" ")
        f.write("\n")

# %%
with open("glove_fr_muse.model", "w") as f:
    f.write(str(len(glove_fr.dictionary))+" "+str(dimensions)+"\n")
    for word in glove_fr.dictionary:
        f.write(word)
        f.write(" ")
        for i in range(0, dimensions):
            f.write(str(glove_fr.word_vectors[glove_fr.dictionary[word]][i]))
            f.write(" ")
        f.write("\n")

# %% [markdown]
# <h2>Aligning vector spaces with MUSE and saving</h2>

# %%
align_models("el","fr", "glove_gk_muse.model","glove_fr_muse.model")

# %%
src_path = './results/25_03_1452/vectors-el.txt'
tgt_path = './results/25_03_1452/vectors-fr_for_merge.txt'

data = data2 = ""
with open(src_path) as fp:
    data = fp.read()

with open(tgt_path) as fp:
    data2 = fp.read()

data += "\n"
data += data2
  
with open ('./results/25_03_1452/merged.vec.txt', 'w') as fp:
    fp.write(data)

# %% [markdown]
# <h2>Load MUSE multilingual models</h2>

# %%
def load_vec(emb_path, nmax=50000):
    vectors = []
    word2id = {}
    with io.open(emb_path, 'r', encoding='utf-8', newline='\n', errors='ignore') as f:
        next(f)
        for i, line in enumerate(f):
            word, vect = line.rstrip().split(' ', 1)
            vect = np.fromstring(vect, sep=' ')
            assert word not in word2id, 'word found twice'
            vectors.append(vect)
            word2id[word] = len(word2id)
            if len(word2id) == nmax:
                break
    id2word = {v: k for k, v in word2id.items()}
    embeddings = np.vstack(vectors)
    return embeddings, id2word, word2id

# %%
src_path = './results/25_03_1452/vectors-el.txt'
tgt_path = './results/25_03_1452/vectors-fr.txt'
nmax = 100000  # maximum number of word embeddings to load

src_embeddings, src_id2word, src_word2id = load_vec(src_path, nmax)
tgt_embeddings, tgt_id2word, tgt_word2id = load_vec(tgt_path, nmax)

# %%
def get_nn(word, src_emb, src_id2word, tgt_emb, tgt_id2word, K=5):
    print("Nearest neighbors of \"%s\":" % word)
    word2id = {v: k for k, v in src_id2word.items()}
    word_emb = src_emb[word2id[word]]
    scores = (tgt_emb / np.linalg.norm(tgt_emb, 2, 1)[:, None]).dot(word_emb / np.linalg.norm(word_emb))
    k_best = scores.argsort()[-K:][::-1]
    for i, idx in enumerate(k_best):
        print('%.4f - %s' % (scores[idx], tgt_id2word[idx]))

# %% [markdown]
# <h2>Testing MUSE multilingual models</h2>

# %%
src_word = 'Ὀδυσσεύς'
get_nn(src_word, src_embeddings, src_id2word, src_embeddings, src_id2word, K=5)
# Out:
# Nearest neighbors of "Ὀδυσσεύς":
# 1.0000 - Ὀδυσσεύς
# 0.8923 - παραπείθω
# 0.8677 - ταλασίφρων
# 0.8657 - κλισία
# 0.8642 - πτολίπορθος

# %%
src_word = 'Καλυψώ'
get_nn(src_word, src_embeddings, src_id2word, tgt_embeddings, tgt_id2word, K=20)
# Out:
# Nearest neighbors of "Καλυψώ":
# 0.6896 - désirer
# 0.6839 - impétueusement
# 0.6756 - Sisyphe
# 0.6732 - peloton
# 0.6518 - prétendre
# 0.6485 - femelle
# 0.6416 - jamais
# 0.6339 - souvenir
# 0.6338 - heureux
# 0.6169 - admirer
# 0.6089 - infortuné
# 0.6001 - durcir
# 0.6001 - exceller
# 0.5923 - penser
# 0.5856 - déjà
# 0.5846 - frère
# 0.5834 - lavoir
# 0.5819 - absent
# 0.5807 - Éole
# 0.5778 - croire

# %% [markdown]
# <h2>Generating Tensorflow Projector files</h2>

# %% [markdown]
# <h2>Visualization (work in progress)</h2>

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3, whiten=True)  # TSNE(n_components=2, n_iter=3000, verbose=2)
df=np.vstack([src_embeddings, tgt_embeddings])
pca.fit(df)

print('Variance explained: %.2f' % pca.explained_variance_ratio_.sum())
# Out:
# Variance explained: 0.32

# %%
tsne = TSNE(perplexity=30, n_components=3, init='pca', n_iter=3500, random_state=12, n_jobs=-1)
df=np.vstack([src_embeddings, tgt_embeddings])
df = tsne.fit(df)

# %%
import matplotlib.pyplot as plt
matplotlib.use('nbagg')
import matplotlib.font_manager as fm
fp1 = fm.FontProperties(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-B.ttf')
 

def plot_similar_word(src_words, src_word2id, src_emb, tgt_words, tgt_word2id, tgt_emb, pca):
    
    if matplotlib.get_backend() == 'nbAgg':          # Instructions for interactive plots
        print("Zoom by moving the mouse up & down while holding down the right mouse button.")

    Y = []
    word_labels = []
    associate_colors={}
    for sw in src_words:
        Y.append(src_emb[src_word2id[sw]])
        word_labels.append(sw)
    for tw in tgt_words:
        Y.append(tgt_emb[tgt_word2id[tw]])
        word_labels.append(tw)
    
    colors = cm.RdYlGn(np.linspace(0, 0.8, len(word_labels)))
    #colors = cm.rainbow(np.linspace(0, 1, len(word_labels)))
    
    for src,trg,color in zip(src_words,tgt_words, colors):
        associate_colors[src]=color
        associate_colors[trg]=color
    

    # find tsne coords for 3 dimensions
    Y = pca.transform(Y)
    x_coords = Y[:, 0]
    y_coords = Y[:, 1]
    z_coords = Y[:, 2]

    # display scatter plot

    fig = plt.figure(figsize=(10, 8), dpi=80)
    ax = Axes3D(fig)
    
    print("getting there")
    
    

    for k, (label, x, y, z) in enumerate(zip(word_labels, x_coords, y_coords,z_coords)):
        ax.scatter(x,y,z,color=associate_colors[label]) 
        ax.text(x,y,z,  '%s' % (label), size=20, zorder=1,  color=associate_colors[label], fontproperties=fp1, fontsize=15) 
        
    print("getting there too")

    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')

    plt.xlim(x_coords.min() - 0.2, x_coords.max() + 0.2)
    plt.ylim(y_coords.min() - 0.2, y_coords.max() + 0.2)
    ax.set_title('Visualization of the multilingual word embedding space')

    plt.show()

# %%
# get random input words
src_words = ['Τροία','νημερτής', 'μήτηρ','κατακτείνω','κλέος',"ἅλς","τύμβος","Καλυψώ"]
tgt_words = ['Troie','dévaster', 'mère','arme','glorieux',"sable","pitoyable","désirer"]

plot_similar_word(src_words, src_word2id, src_embeddings, tgt_words, tgt_word2id, tgt_embeddings, pca)
# Out:
# Zoom by moving the mouse up & down while holding down the right mouse button.
# <img src="data:image/png;base64,..." width="799.3333333333334">
# getting there
# getting there too
